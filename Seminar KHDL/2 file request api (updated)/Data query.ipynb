# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\nhatd\appdata\roaming\python\python311\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nhatd\appdata\roaming\python\python311\site-packages (from requests) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nhatd\appdata\roaming\python\python311\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nhatd\appdata\roaming\python\python311\site-packages (from requests) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nhatd\appdata\roaming\python\python311\site-packages (from requests) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping C:\Users\Nhatd\AppData\Roaming\Python\Python311\site-packages\pip-23.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Nhatd\AppData\Roaming\Python\Python311\site-packages\pip-23.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Nhatd\AppData\Roaming\Python\Python311\site-packages\pip-23.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Nhatd\AppData\Roaming\Python\Python311\site-packages\pip-23.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Nhatd\AppData\Roaming\Python\Python311\site-packages\pip-23.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Nhatd\AppData\Roaming\Python\Python311\site-packages\pip-23.1.2.dist-info due to invalid metadata entry 'name'

# %% [markdown]
# # Lấy danh sách json phim upcoming

# %%
import requests

url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ODFkOGIwZjMzMTYzMTgxZDk2ZDYxZmEyMWVhMTZhNCIsInN1YiI6IjY1MWRhNmVkYzUwYWQyMDBhZDgyZDRlYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.jfoB836ahuG6GYsOsAOTORYACLJRO6V7mm0_IUxMLv4"
}

response = requests.get(url, headers=headers)

#print(response.text)

# %% [markdown]
# # ghi dữ liệu vào file Json và lưu về máy

# %%
import json
import requests
import pandas as pd

url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ODFkOGIwZjMzMTYzMTgxZDk2ZDYxZmEyMWVhMTZhNCIsInN1YiI6IjY1MWRhNmVkYzUwYWQyMDBhZDgyZDRlYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.jfoB836ahuG6GYsOsAOTORYACLJRO6V7mm0_IUxMLv4"
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    # Chuyển đổi nội dung JSON thành đối tượng Python
    json_data = json.loads(response.text)

    # Lưu JSON vào một tệp văn bản
    with open("output_upcoming_id.json", "w") as file:
        json.dump(json_data, file, indent=4)
else:
    print("Lỗi khi tải dữ liệu từ API")
#print(response.text)

# %% [markdown]
# # đọc file json vừa tạo

# %%
with open("output_upcoming_id.json", "r") as file:
    json_dict = json.load(file)

# %%
df = pd.DataFrame(json_dict["results"])
df
# Out:
#     adult                     backdrop_path  \
# 0   False  /xgGGinKRL8xeRkaAR9RMbtyk60y.jpg
# 1   False  /f1AQhx6ZfGhPZFTVKgxG91PhEYc.jpg
# 2   False  /5a4JdoFwll5DRtKMe7JLuGQ9yJm.jpg
# 3   False  /ehumsuIBbgAe1hg343oszCLrAfI.jpg
# 4   False  /zgQQF04u3OgNBJqClRNby1FPz9s.jpg
# 5   False  /dZbLqRjjiiNCpTYzhzL2NMvz4J0.jpg
# 6   False  /iiXliCeykkzmJ0Eg9RYJ7F2CWSz.jpg
# 7   False  /zZnsfR6BRqtxyLyAhsi2TMukEBx.jpg
# 8   False  /bckxSN9ueOgm0gJpVJmPQrecWul.jpg
# 9   False  /yUpkacZw40XLWPzFGsGBU1199AL.jpg
# 10  False  /igwshQHV36aBkPyWp7En5P4Kn2V.jpg
# 11  False  /iEFuHjqrE059SmflBva1JzDJutE.jpg
# 12  False  /kszooR7v1TLFM4pzx6IkKq2jDAN.jpg
# 13  False  /bWIIWhnaoWx3FTVXv6GkYDv3djL.jpg
# 14  False  /c7MRmF3LMiBWokedmdQl3roTUv2.jpg
# 15  False  /qElNES0sHVQcbzvGrTx7ccpGzij.jpg
# 16  False  /sQLMaESdeELB7Dl8HdxfGlZYRzu.jpg
# 17  False  /8KJMOKyl9rpgb9ELEwhfBMIaTHw.jpg
# 18  False  /w1ZeZ8XYTBCovnXi9bwi7D7glM4.jpg
# 19  False  /dp0rdbGSbZTyWumnbWspXQp87hA.jpg
#
#                             genre_ids       id original_language  \
# 0          [16, 10751, 10402, 14, 35]   901362                en
# 1                     [18, 36, 10752]   753342                en
# 2                     [28, 10749, 18]   695721                en
# 3                 [16, 10751, 14, 12]  1022796                en
# 4            [16, 10751, 28, 878, 35]   893723                en
# 5                            [27, 53]   951491                en
# 6                        [28, 53, 80]   762430                en
# 7                  [16, 28, 80, 9648]  1047041                ja
# 8                        [28, 12, 14]   572802                en
# 9                     [35, 10751, 14]   787699                en
# 10                     [27, 53, 9648]  1071215                en
# 11  [16, 10751, 14, 28, 10749, 10402]   496450                fr
# 12                     [18, 80, 9648]   915935                fr
# 13                      [28, 18, 878]   940721                ja
# 14                           [53, 18]   798362                en
# 15                      [878, 28, 18]   842675                zh
# 16                           [35, 18]   840430                en
# 17                [10751, 16, 14, 35]  1139087                en
# 18                       [28, 80, 53]   891699                en
# 19                         [27, 9648]  1024773                en
#
#                                        original_title  \
# 0                                Trolls Band Together
# 1                                            Napoleon
# 2   The Hunger Games: The Ballad of Songbirds & Sn...
# 3                                                Wish
# 4                        PAW Patrol: The Mighty Movie
# 5                                               Saw X
# 6                                         Retribution
# 7                                 名探偵コナン 黒鉄の魚影（サブマリン）
# 8                        Aquaman and the Lost Kingdom
# 9                                               Wonka
# 10                                       Thanksgiving
# 11                               Miraculous - le film
# 12                               Anatomie d'une chute
# 13                                            ゴジラ-1.0
# 14                          The Marsh King's Daughter
# 15                                              流浪地球2
# 16                                      The Holdovers
# 17                                 Once Upon a Studio
# 18                                       Silent Night
# 19                                    It Lives Inside
#
#                                              overview  popularity  \
# 0   When Branch’s brother, Floyd, is kidnapped for...    1121.642
# 1   An epic that details the checkered rise and fa...     490.701
# 2   64 years before he becomes the tyrannical pres...     435.969
# 3   Asha, a sharp-witted idealist, makes a wish so...     345.581
# 4   A magical meteor crash lands in Adventure City...     323.504
# 5   Between the events of 'Saw' and 'Saw II', a si...     318.944
# 6   When a mysterious caller puts a bomb under his...     292.328
# 7   Many engineers from around the world gather at...     261.404
# 8   Black Manta, still driven by the need to aveng...     195.950
# 9   Willy Wonka – chock-full of ideas and determin...     180.822
# 10  After a Black Friday riot ends in tragedy, a m...     165.070
# 11  A life of an ordinary Parisian teenager Marine...     164.624
# 12  A woman is suspected of her husband’s murder, ...     130.270
# 13  In postwar Japan, a new terror rises. Will the...     140.554
# 14  Helena, a woman living a seemingly ordinary li...     132.404
# 15  Humans built huge engines on the surface of th...     114.648
# 16  A curmudgeonly instructor at a New England pre...     135.617
# 17  Created for Disney's 100th anniversary, the sh...      85.189
# 18  A tormented father witnesses his young son die...      88.767
# 19  Desperate to fit in at school, Sam rejects her...      92.661
#
#                          poster_path release_date  \
# 0   /qV4fdXXUm5xNlEJ2jw7af3XxuQB.jpg   2023-10-12
# 1   /jE5o7y9K6pZtWNNMEw3IdpHuncR.jpg   2023-11-22
# 2   /mBaXZ95R2OxueZhvQbcEWy2DqyO.jpg   2023-11-15
# 3   /AcoVfiv1rrWOmAdpnAMnM56ki19.jpg   2023-11-13
# 4   /aTvePCU7exLepwg5hWySjwxojQK.jpg   2023-09-21
# 5   /aQPeznSu7XDTrrdCtT5eLiu52Yu.jpg   2023-09-26
# 6   /oUmmY7QWWn7OhKlcPOnirHJpP1F.jpg   2023-08-23
# 7   /ksQ8uNgoWsVH6a0oPB6zx08pOwU.jpg   2023-04-14
# 8   /8xV47NDrjdZDpkVcCFqkdHa3T0C.jpg   2023-12-20
# 9   /qhb1qOilapbapxWQn9jtRCMwXJF.jpg   2023-12-06
# 10  /lhmdKoZciQsD6pOxIi0ZkXudISw.jpg   2023-11-16
# 11  /dQNJ8SdCMn3zWwHzzQD2xrphR1X.jpg   2023-07-05
# 12  /kQs6keheMwCxJxrzV83VUwFtHkB.jpg   2023-08-23
# 13  /hkxxMIGaiCTmrEArK7J56JTKUlB.jpg   2023-11-03
# 14  /bcuEjrwhp5HgEUnFe5lc4xpEqzt.jpg   2023-09-28
# 15  /pR858ihc6Ls9xohpdRJVjV787ml.jpg   2023-01-22
# 16   /VHSzNBTwxV8vh7wylo7O9CLdac.jpg   2023-10-27
# 17  /hr8ZtwdbtjBquxlTCrczr685K5T.jpg   2023-09-24
# 18  /tlcuhdNMKNGEVpGqBZrAaOOf1A6.jpg   2023-11-30
# 19  /73gIfV8gDwkVgUrFDzt4TfZC9Zc.jpg   2023-09-06
#
#                                                 title  video  vote_average  \
# 0                                Trolls Band Together  False         7.218
# 1                                            Napoleon  False         6.456
# 2   The Hunger Games: The Ballad of Songbirds & Sn...  False         7.294
# 3                                                Wish  False         6.700
# 4                        PAW Patrol: The Mighty Movie  False         6.900
# 5                                               Saw X  False         7.400
# 6                                         Retribution  False         6.991
# 7               Detective Conan: Black Iron Submarine  False         6.582
# 8                        Aquaman and the Lost Kingdom  False         0.000
# 9                                               Wonka  False         0.000
# 10                                       Thanksgiving  False         6.187
# 11          Miraculous: Ladybug & Cat Noir, The Movie  False         7.800
# 12                                  Anatomy of a Fall  False         7.828
# 13                                 Godzilla Minus One  False         8.200
# 14                          The Marsh King's Daughter  False         6.900
# 15                             The Wandering Earth II  False         7.221
# 16                                      The Holdovers  False         8.000
# 17                                 Once Upon a Studio  False         8.437
# 18                                       Silent Night  False         7.600
# 19                                    It Lives Inside  False         5.773
#
#     vote_count
# 0          229
# 1          430
# 2          498
# 3           66
# 4          181
# 5         1173
# 6          696
# 7           49
# 8            0
# 9            0
# 10          67
# 11         671
# 12         357
# 13          10
# 14          37
# 15         400
# 16          61
# 17         246
# 18           6
# 19          88

# %%
df["id"]
# Out:
# 0      901362
# 1      753342
# 2      695721
# 3     1022796
# 4      893723
# 5      951491
# 6      762430
# 7     1047041
# 8      572802
# 9      787699
# 10    1071215
# 11     496450
# 12     915935
# 13     940721
# 14     798362
# 15     842675
# 16     840430
# 17    1139087
# 18     891699
# 19    1024773
# Name: id, dtype: int64

# %% [markdown]
# # Lấy danh sách id IMDB từ id trên TMDB của các bộ phim sắp chiếu và ghi vào file JSON

# %%
import requests
id_list = df["id"].tolist()
id_list
base_url = "https://api.themoviedb.org/3/movie/"
language = "us-US"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjN2ZmNDQyZWY5MWQyMGQ1MmJjMDhhOTgzMWFkOGVlZiIsInN1YiI6IjY1MjE2ZjRlYzFmZmJkMDExYjQzNTJlOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.G4CsJ9HQFeIKiIKirMnBbgjnFxo71z-36lqU2hLaUG8"
}
with open("output_IMDB_id.json", "w") as file:
    pass
data_list = []
for movie_id in id_list:
    url = f"{base_url}{movie_id}?language={language}"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
    # Chuyển đổi nội dung JSON thành đối tượng Python
        json_data = json.loads(response.text)
    data_list.append(json_data)
result_dict = {
    "results": data_list
}
# Mở tệp tin để ghi dữ liệu
with open("output_IMDB_id.json", "w") as file:
    json.dump(result_dict, file, indent=4)

# %% [markdown]
# # Đọc file JSON imdb id vừa tạo

# %%
with open("output_IMDB_id.json", "r") as file:
    json_dict = json.load(file)
    formatted_json = json.dumps(json_dict, indent=4)
    #print(formatted_json)

# %%
df = pd.DataFrame(json_dict["results"])
df
# Out:
#     adult                     backdrop_path  \
# 0   False  /xgGGinKRL8xeRkaAR9RMbtyk60y.jpg
# 1   False  /f1AQhx6ZfGhPZFTVKgxG91PhEYc.jpg
# 2   False  /5a4JdoFwll5DRtKMe7JLuGQ9yJm.jpg
# 3   False  /ehumsuIBbgAe1hg343oszCLrAfI.jpg
# 4   False  /zgQQF04u3OgNBJqClRNby1FPz9s.jpg
# 5   False  /dZbLqRjjiiNCpTYzhzL2NMvz4J0.jpg
# 6   False  /iiXliCeykkzmJ0Eg9RYJ7F2CWSz.jpg
# 7   False  /zZnsfR6BRqtxyLyAhsi2TMukEBx.jpg
# 8   False  /bckxSN9ueOgm0gJpVJmPQrecWul.jpg
# 9   False  /yUpkacZw40XLWPzFGsGBU1199AL.jpg
# 10  False  /igwshQHV36aBkPyWp7En5P4Kn2V.jpg
# 11  False  /iEFuHjqrE059SmflBva1JzDJutE.jpg
# 12  False  /kszooR7v1TLFM4pzx6IkKq2jDAN.jpg
# 13  False  /bWIIWhnaoWx3FTVXv6GkYDv3djL.jpg
# 14  False  /c7MRmF3LMiBWokedmdQl3roTUv2.jpg
# 15  False  /qElNES0sHVQcbzvGrTx7ccpGzij.jpg
# 16  False  /sQLMaESdeELB7Dl8HdxfGlZYRzu.jpg
# 17  False  /8KJMOKyl9rpgb9ELEwhfBMIaTHw.jpg
# 18  False  /w1ZeZ8XYTBCovnXi9bwi7D7glM4.jpg
# 19  False  /dp0rdbGSbZTyWumnbWspXQp87hA.jpg
#
#                                 belongs_to_collection     budget  \
# 0   {'id': 489724, 'name': 'The Trolls Collection'...   95000000
# 1                                                None  165000000
# 2                                                None  100000000
# 3                                                None  175000000
# 4   {'id': 893731, 'name': 'PAW Patrol (Theatrical...   30000000
# 5   {'id': 656, 'name': 'Saw Collection', 'poster_...   13000000
# 6                                                None   20000000
# 7   {'id': 39199, 'name': 'Detective Conan Collect...          0
# 8   {'id': 573693, 'name': 'Aquaman Collection', '...  215000000
# 9                                                None  125000000
# 10  {'id': 1211888, 'name': 'Thanksgiving Collecti...   15000000
# 11                                               None   86000000
# 12                                               None    6200000
# 13                                               None   15000000
# 14                                               None          0
# 15  {'id': 1073029, 'name': 'Wandering Earth Colle...   73801827
# 16                                               None          0
# 17                                               None          0
# 18                                               None          0
# 19                                               None          0
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 1   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 10749, '...
# 3   [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 4   [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 5   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 6   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 7   [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9   [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 10  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 11  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 12  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 13  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 14  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 15  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 16  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 17  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 18  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 19  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
#
#                                              homepage       id     imdb_id  \
# 0   https://www.dreamworks.com/movies/trolls-band-...   901362  tt14362112
# 1                          https://www.napoleon.movie   753342  tt13287846
# 2                           https://hungergames.movie   695721  tt10545296
# 3                      https://movies.disney.com/wish  1022796  tt11304740
# 4                         https://www.pawpatrol.movie   893723  tt15837338
# 5                               https://www.saw.movie   951491  tt21807222
# 6        https://www.lionsgate.com/movies/retribution   762430   tt6906292
# 7                                                      1047041  tt27521477
# 8                         http://www.aquamanmovie.com   572802   tt9663764
# 9                          https://www.wonkamovie.com   787699   tt6166392
# 10                          http://thanksgiving.movie  1071215   tt1448754
# 11             https://www.netflix.com/title/81383247   496450  tt10364034
# 12                         http://anatomyofafall.film   915935  tt17009710
# 13                                                      940721  tt23289160
# 14  https://www.lionsgate.com/movies/the-marsh-kin...   798362   tt8002382
# 15  https://trinitycineasia.com/in-cinemas/the-wan...   842675  tt13539646
# 16             http://focusfeatures.com/the-holdovers   840430  tt14849194
# 17                                                     1139087  tt28035641
# 18                                                      891699  tt15799866
# 19        https://neonrated.com/films/it-lives-inside  1024773  tt15683734
#
#    original_language                                     original_title  ...  \
# 0                 en                               Trolls Band Together  ...
# 1                 en                                           Napoleon  ...
# 2                 en  The Hunger Games: The Ballad of Songbirds & Sn...  ...
# 3                 en                                               Wish  ...
# 4                 en                       PAW Patrol: The Mighty Movie  ...
# 5                 en                                              Saw X  ...
# 6                 en                                        Retribution  ...
# 7                 ja                                名探偵コナン 黒鉄の魚影（サブマリン）  ...
# 8                 en                       Aquaman and the Lost Kingdom  ...
# 9                 en                                              Wonka  ...
# 10                en                                       Thanksgiving  ...
# 11                fr                               Miraculous - le film  ...
# 12                fr                               Anatomie d'une chute  ...
# 13                ja                                            ゴジラ-1.0  ...
# 14                en                          The Marsh King's Daughter  ...
# 15                zh                                              流浪地球2  ...
# 16                en                                      The Holdovers  ...
# 17                en                                 Once Upon a Studio  ...
# 18                en                                       Silent Night  ...
# 19                en                                    It Lives Inside  ...
#
#    release_date    revenue runtime  \
# 0    2023-10-12  145800000      92
# 1    2023-11-22   78800000     158
# 2    2023-11-15  169082191     157
# 3    2023-11-13   49000000      95
# 4    2023-09-21  192400000      92
# 5    2023-09-26  100900000     118
# 6    2023-08-23   16700000      91
# 7    2023-04-14          0     110
# 8    2023-12-20          0     124
# 9    2023-12-06          0     117
# 10   2023-11-16   29100000     106
# 11   2023-07-05   38955339     107
# 12   2023-08-23   17700000     152
# 13   2023-11-03   14000000     125
# 14   2023-09-28          0     108
# 15   2023-01-22  604380922     173
# 16   2023-10-27          0     133
# 17   2023-09-24          0       9
# 18   2023-11-30          0     104
# 19   2023-09-06    4800000      99
#
#                                      spoken_languages           status  \
# 0   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 1   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 2   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 3   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 4   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 5   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 6   [{'english_name': 'German', 'iso_639_1': 'de',...         Released
# 7   [{'english_name': 'Japanese', 'iso_639_1': 'ja...         Released
# 8   [{'english_name': 'English', 'iso_639_1': 'en'...  Post Production
# 9   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 10  [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 11  [{'english_name': 'French', 'iso_639_1': 'fr',...         Released
# 12  [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 13  [{'english_name': 'Japanese', 'iso_639_1': 'ja...         Released
# 14  [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 15  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...         Released
# 16  [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 17  [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 18  [{'english_name': 'No Language', 'iso_639_1': ...         Released
# 19  [{'english_name': 'English', 'iso_639_1': 'en'...         Released
#
#                                               tagline  \
# 0             There are some new trolls on the block.
# 1      He came from nothing. He conquered everything.
# 2                     Everyone hungers for something.
# 3                       Be careful what you wish for.
# 4                                Unleash your powers.
# 5                       Witness the return of Jigsaw.
# 6                        All roads lead to the truth.
# 7
# 8                                The tide is turning.
# 9   Every good thing in this world started with a ...
# 10                        There will be no leftovers.
# 11           The fate of the world is in their hands.
# 12                                     Did she do it?
# 13                 Postwar Japan. From zero to minus.
# 14                          Fear the past or face it.
# 15
# 16                                Discomfort and joy.
# 17          100 years of Disney magic comes together.
# 18                   Action speaks louder than words.
# 19                            You can't contain evil.
#
#                                                 title  video vote_average  \
# 0                                Trolls Band Together  False        7.218
# 1                                            Napoleon  False        6.458
# 2   The Hunger Games: The Ballad of Songbirds & Sn...  False        7.294
# 3                                                Wish  False        6.700
# 4                        PAW Patrol: The Mighty Movie  False        6.900
# 5                                               Saw X  False        7.400
# 6                                         Retribution  False        6.991
# 7               Detective Conan: Black Iron Submarine  False        6.700
# 8                        Aquaman and the Lost Kingdom  False        0.000
# 9                                               Wonka  False        0.000
# 10                                       Thanksgiving  False        6.187
# 11          Miraculous: Ladybug & Cat Noir, The Movie  False        7.800
# 12                                  Anatomy of a Fall  False        7.828
# 13                                 Godzilla Minus One  False        8.200
# 14                          The Marsh King's Daughter  False        6.900
# 15                             The Wandering Earth II  False        7.221
# 16                                      The Holdovers  False        7.951
# 17                                 Once Upon a Studio  False        8.437
# 18                                       Silent Night  False        7.600
# 19                                    It Lives Inside  False        5.773
#
#    vote_count
# 0         229
# 1         428
# 2         498
# 3          66
# 4         181
# 5        1173
# 6         696
# 7          48
# 8           0
# 9           0
# 10         67
# 11        671
# 12        357
# 13         10
# 14         37
# 15        400
# 16         61
# 17        246
# 18          6
# 19         88
#
# [20 rows x 25 columns]

# %%
upcoming_data = df[['id', 'imdb_id', 'budget', 'revenue']]
upcoming_data
# Out:
#          id     imdb_id     budget    revenue
# 0    901362  tt14362112   95000000  145800000
# 1    753342  tt13287846  165000000   78800000
# 2    695721  tt10545296  100000000  169082191
# 3   1022796  tt11304740  175000000   49000000
# 4    893723  tt15837338   30000000  192400000
# 5    951491  tt21807222   13000000  100900000
# 6    762430   tt6906292   20000000   16700000
# 7   1047041  tt27521477          0          0
# 8    572802   tt9663764  215000000          0
# 9    787699   tt6166392  125000000          0
# 10  1071215   tt1448754   15000000   29100000
# 11   496450  tt10364034   86000000   38955339
# 12   915935  tt17009710    6200000   17700000
# 13   940721  tt23289160   15000000   14000000
# 14   798362   tt8002382          0          0
# 15   842675  tt13539646   73801827  604380922
# 16   840430  tt14849194          0          0
# 17  1139087  tt28035641          0          0
# 18   891699  tt15799866          0          0
# 19  1024773  tt15683734          0    4800000

# %% [markdown]
# ## đã có list data của phim upcoming, tiếp theo cần dựa vô cái data frame này để đi truy vấn người tham gia làm từng bộ phim, cần truy vấn SQL trên python, postgres để lấy rating, imdb_id của mấy bộ phim quá khứ liên quan đó
