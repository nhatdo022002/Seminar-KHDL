# %%
pip install requests

# %% [markdown]
# # Đọc danh sách các phim đã được truy vấn từ 1 bộ chưa chiếu cụ thể

# %% [markdown]
# ví dụ ở đây thì là của bộ Five night at freddy

# %%
"tt0116508"
"tt0122946"
"tt10039344"
"tt1072754"
"tt18083578"
"tt7164084"
"tt8009314"
"tt8426594"
"tt8745960"
"tt0111127"
"tt0183808"
"tt0758757"
"tt1701990"
"tt2651916"
"tt27403906"
"tt4929720"
"tt7074750"
"tt0104787"
"tt0245674"
"tt21651560"
"tt3859272"
imdb_list = [
    "tt0116508", "tt0122946", "tt10039344", "tt1072754", "tt18083578",
    "tt7164084", "tt8009314", "tt8426594", "tt8745960", "tt0111127",
    "tt0183808", "tt0758757", "tt1701990", "tt2651916", "tt27403906",
    "tt4929720", "tt7074750", "tt0104787", "tt0245674", "tt21651560",
    "tt3859272"
]
len(imdb_list)
# Out:
# 21

# %% [markdown]
# # từ danh sách imdb_id trên sẽ đi truy ngược lấy id trên web the moviedb

# %% [markdown]
# lấy ví dụ 1 truy vấn từ 1 imdb_id đầu tiên:

# %%
import requests
url = "https://api.themoviedb.org/3/find/tt7164084?api_key=781d8b0f33163181d96d61fa21ea16a4&external_source=imdb_id"
headers = {"accept": "application/json"}
response = requests.get(url, headers=headers)
#print(response.text)

# %% [markdown]
# Lấy tất cả tmdb_id từ list imdb_id

# %%
import json
import requests
import pandas as pd
#id_list = df["id"].tolist()
imdb_list
base_url = "https://api.themoviedb.org/3/find/"

headers = {
    "accept": "application/json",
    #"Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjN2ZmNDQyZWY5MWQyMGQ1MmJjMDhhOTgzMWFkOGVlZiIsInN1YiI6IjY1MjE2ZjRlYzFmZmJkMDExYjQzNTJlOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.G4CsJ9HQFeIKiIKirMnBbgjnFxo71z-36lqU2hLaUG8"
}
with open("output_IMDB_id.json", "w") as file:
    pass
data_list = []
for movie_id in imdb_list:
    url = f"{base_url}{movie_id}?api_key=781d8b0f33163181d96d61fa21ea16a4&external_source=imdb_id"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
    # Chuyển đổi nội dung JSON thành đối tượng Python
        json_data = json.loads(response.text)
    data_list.append(json_data)
result_dict = {
    "results": data_list
}
# Mở tệp tin để ghi dữ liệu
with open("output_TMDB_id.json", "w") as file:
    json.dump(result_dict, file, indent=4)

# %%
with open("output_TMDB_id.json", "r") as file:
    json_dict = json.load(file)
    
movie_results_list = [result['movie_results'] for result in json_dict['results']]
# Gộp tất cả các kết quả của "movie_results" thành một danh sách duy nhất
merged_movie_results = [movie for sublist in movie_results_list for movie in sublist]
# Tạo DataFrame từ danh sách các kết quả "movie_results"
movie_results_df = pd.DataFrame(merged_movie_results)

# Hiển thị DataFrame mới tạo
movie_results_df
# Out:
#     adult                     backdrop_path       id               title  \
# 0   False  /xUPcTaq3dKOK3tInplsX7qQ0Uzb.jpg    36915  Heaven's Prisoners
# 1   False  /coPfnkYBodJ5rsunfjWapz8KuZq.jpg    30492         Animal Room
# 2   False  /zETkzgle7c6wAeW11snnVUBp67S.jpg   599975           Countdown
# 3   False  /uTX4CPryKPVzrI42unG1VrI002o.jpg    79073    Messages Deleted
# 4   False  /jP3FatCTHc460ZGW57q9ypTdBqu.jpg   937249          57 Seconds
# 5   False  /5j5UiJoVhoGS2JEdm53srUOlelc.jpg   579789          Unintended
# 6   False  /3C14xx4RteMksSUwgYfI52B8Iu6.jpg   508138                Burn
# 7   False  /9NoBsVuZA1O51xsUkTTHZgqGBs0.jpg   541560            The Wind
# 8   False  /w4SXVDLmsqZ1gjLC5sgQCZUvuoC.jpg   537788   Daniel Isn't Real
# 9   False  /nqdwkjcIN3AFvV1ITbCHKQ4GRBT.jpg    11592          Serial Mom
# 10  False                              None   141319      Spanish Judges
# 11  False                              None    54729      The Insurgents
# ...

# %% [markdown]
# # Lấy 2 feature của phim cũ là ID để truy ngược lại 'budget' và 'revenue', lấy thêm feature 'Popularity' để đẩy vào model

# %%
new_df = movie_results_df[['id', 'popularity']]
#new_df.columns = ['New_A', 'B']
new_df
# Out:
#          id  popularity
# 0     36915      11.246
# 1     30492       2.287
# 2    599975      19.452
# 3     79073       5.692
# 4    937249     157.141
# 5    579789       1.889
# 6    508138      24.175
# 7    541560      12.101
# 8    537788      11.163
# 9     11592      22.391
# 10   141319       3.357
# 11    54729       0.943
# 12    68684      19.276
# 13   229702       3.579
# 14  1110586      10.483
# 15   360007       6.998
# 16   151062       3.206
# 17     9378      30.798
# 18  1005776      19.034
# 19   413857      17.330

# %% [markdown]
# ## Từ list này mình làm y như cái cách lấy thông tin imdb_id để tìm 'budget' và 'revenue' thay vì tim 'imdb_id'

# %%
import requests
id_list = new_df["id"].tolist()
id_list
base_url = "https://api.themoviedb.org/3/movie/"
language = "us-US"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjN2ZmNDQyZWY5MWQyMGQ1MmJjMDhhOTgzMWFkOGVlZiIsInN1YiI6IjY1MjE2ZjRlYzFmZmJkMDExYjQzNTJlOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.G4CsJ9HQFeIKiIKirMnBbgjnFxo71z-36lqU2hLaUG8"
}
with open("budget_revenue_TMDB_id.json", "w") as file:
    pass
data_list = []
for movie_id in id_list:
    url = f"{base_url}{movie_id}?language={language}"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
    # Chuyển đổi nội dung JSON thành đối tượng Python
        json_data = json.loads(response.text)
    data_list.append(json_data)
result_dict = {
    "results": data_list
}
# Mở tệp tin để ghi dữ liệu
with open("budget_revenue_TMDB_id.json", "w") as file:
    json.dump(result_dict, file, indent=4)

# %% [markdown]
# ## Đọc file json vừa tạo

# %%
with open("budget_revenue_TMDB_id.json", "r") as file:
    json_dict = json.load(file)
    formatted_json = json.dumps(json_dict, indent=4)
    #print(formatted_json)

# %%
df_budget = pd.DataFrame(json_dict["results"])
df_budget
# Out:
#     adult                     backdrop_path  \
# 0   False  /xUPcTaq3dKOK3tInplsX7qQ0Uzb.jpg
# 1   False  /coPfnkYBodJ5rsunfjWapz8KuZq.jpg
# 2   False  /zETkzgle7c6wAeW11snnVUBp67S.jpg
# 3   False  /uTX4CPryKPVzrI42unG1VrI002o.jpg
# 4   False  /jP3FatCTHc460ZGW57q9ypTdBqu.jpg
# 5   False  /5j5UiJoVhoGS2JEdm53srUOlelc.jpg
# 6   False  /3C14xx4RteMksSUwgYfI52B8Iu6.jpg
# 7   False  /9NoBsVuZA1O51xsUkTTHZgqGBs0.jpg
# 8   False  /w4SXVDLmsqZ1gjLC5sgQCZUvuoC.jpg
# 9   False  /nqdwkjcIN3AFvV1ITbCHKQ4GRBT.jpg
# 10  False                              None
# 11  False                              None
# 12  False  /dIejmkCP46vN5a17u44phOGyAVR.jpg
# 13  False                              None
# 14  False  /8Fm7orQofGDS7mA5EikK3A4dQbI.jpg
# 15  False  /v0jz0Lln6G7HyKnBL4qvmIki3Yr.jpg
# 16  False  /orBmK3c1AylG9kjAgHpV9LpOQZF.jpg
# 17  False  /okXFpyNquUVMvKRoaWjQOouvacl.jpg
# 18  False  /o8tThg5KqX3t32vbAIxNuS8Fmlj.jpg
# 19  False  /pHdCS3FerQhAklu2JDEgpIuv5fP.jpg
#
# ...

# %% [markdown]
# ## lấy mấy cái feature quan trọng:

# %%
df_budget_quan_trong = df_budget[['imdb_id', 'budget', 'revenue']]
df_budget_quan_trong
# Out:
#        imdb_id    budget   revenue
# 0    tt0116508  25000000   5009305
# 1    tt0122946         0         0
# 2   tt10039344   6500000  48021766
# 3    tt1072754         0         0
# 4   tt18083578         0         0
# 5    tt7164084         0         0
# 6    tt8009314         0     25373
# 7    tt8426594         0         0
# 8    tt8745960         0         0
# 9    tt0111127  13000000   7820688
# 10   tt0183808   3500000         0
# 11   tt0758757    200000         0
# 12   tt1701990  10000000         0
# 13   tt2651916         0         0
# 14  tt27403906         0         0
# 15   tt4929720         0         0
# 16   tt0104787         0         0
# 17   tt0245674  42000000  68467960
# 18  tt21651560         0         0
# 19   tt3859272         0         0

# %%
merged_df = pd.concat([new_df, df_budget_quan_trong], axis=1)
merged_df
# Out:
#          id  popularity     imdb_id    budget   revenue
# 0     36915      11.246   tt0116508  25000000   5009305
# 1     30492       2.287   tt0122946         0         0
# 2    599975      19.452  tt10039344   6500000  48021766
# 3     79073       5.692   tt1072754         0         0
# 4    937249     157.141  tt18083578         0         0
# 5    579789       1.889   tt7164084         0         0
# 6    508138      24.175   tt8009314         0     25373
# 7    541560      12.101   tt8426594         0         0
# 8    537788      11.163   tt8745960         0         0
# 9     11592      22.391   tt0111127  13000000   7820688
# 10   141319       3.357   tt0183808   3500000         0
# 11    54729       0.943   tt0758757    200000         0
# 12    68684      19.276   tt1701990  10000000         0
# 13   229702       3.579   tt2651916         0         0
# 14  1110586      10.483  tt27403906         0         0
# 15   360007       6.998   tt4929720         0         0
# ...

# %% [markdown]
# ## Dùng popularity, budget, revenue, rating, numvotes để đưa vào model linear regression
