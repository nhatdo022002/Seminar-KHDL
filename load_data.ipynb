# %%
import json
import requests
import pandas as pd

url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ODFkOGIwZjMzMTYzMTgxZDk2ZDYxZmEyMWVhMTZhNCIsInN1YiI6IjY1MWRhNmVkYzUwYWQyMDBhZDgyZDRlYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.jfoB836ahuG6GYsOsAOTORYACLJRO6V7mm0_IUxMLv4"
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    # Chuyển đổi nội dung JSON thành đối tượng Python
    json_data = json.loads(response.text)

    # Lưu JSON vào một tệp văn bản
    with open("output_upcoming_id.json", "w") as file:
        json.dump(json_data, file, indent=4)
else:
    print("Lỗi khi tải dữ liệu từ API")
#print(response.text)

# %%
with open("output_upcoming_id.json", "r") as file:
    json_dict = json.load(file)

# %%
df = pd.DataFrame(json_dict["results"])
df
# Out:
#     adult                     backdrop_path                   genre_ids  \
# 0   False  /7NRGAtu8E4343NSKwhkgmVRDINw.jpg                  [27, 9648]
# 1   False  /pA3vdhadJPxF5GA1uo8OPTiNQDT.jpg                    [28, 18]
# 2   False  /mv8M0PqQYicndU7TGgBAHrI4uUo.jpg                    [27, 53]
# 3   False  /45zVtZx6Tzx3RKeDziK25K9geFf.jpg  [16, 10751, 10402, 14, 35]
# 4   False  /xHqTnPtpd9Qd7R0fVtoqxZYM67Q.jpg                [80, 53, 28]
# 5   False  /mfm4srsPALxaeOMFFFJ0drXTyXy.jpg                    [35, 12]
# 6   False  /feSiISwgEpVzR1v3zv2n2AU4ANJ.jpg               [28, 12, 878]
# 7   False  /cRdA9xjHBbobw4LJFsQ3j1CgpVq.jpg                    [27, 53]
# 8   False  /cofs7Y72FkRjALbOOOz8q7Uty6h.jpg                    [18, 53]
# 9   False  /a0GM57AnJtNi7lMOCamniiyV10W.jpg            [16, 12, 14, 18]
# 10  False  /qZOuoBoKCDLSm1EvYz2eBub8Cto.jpg         [16, 12, 14, 10751]
# 11  False  /hon92J1oqdrTwcGHXG64G2bXqrJ.jpg               [28, 12, 878]
# 12  False  /mEcCz4Nzw57wJIXo6g69q9NUQih.jpg         [16, 10751, 14, 12]
# 13  False  /8g9ZdvHX6jszRY71aVtpRUmHQzJ.jpg                    [18, 53]
# 14  False  /wOYDsD7WIKsz5DtrnjsvCcEyFJa.jpg             [36, 18, 10752]
# 15  False  /5ut2rC5H1YE0GnNPpl1csnNvqum.jpg                [28, 18, 80]
# 16  False  /eXX9PqCgbTVYnnlbGuAz7Lk4E86.jpg                    [27, 12]
# 17  False  /drfl2eWipiibW3u3Ybx9HQ8VgIn.jpg              [27, 9648, 53]
# 18  False  /rron9HAuS9s7zBF8iCX1tsafxUo.jpg                 [18, 10749]
# 19  False  /3xYPGRUsXCZj7rKOzvOY84JCafK.jpg                 [18, 10749]
#
#          id original_language  \
# 0    507089                en
# 1    678512                en
# 2    744857                es
# 3    901362                en
# 4    958006                en
# 5    912908                en
# 6    609681                en
# 7    663712                en
# 8    944952                en
# 9    508883                ja
# 10   939338                fr
# 11   695721                en
# 12  1022796                en
# 13   958182                es
# 14   753342                en
# 15  1093485                cn
# 16  1145851                es
# 17   841742                fr
# 18   666277                en
# 19  1020006                en
#
#                                        original_title  \
# 0                             Five Nights at Freddy's
# 1                                    Sound of Freedom
# 2                             Cuando acecha la maldad
# 3                                Trolls Band Together
# 4                                       The Kill Room
# 5                                              Strays
# 6                                         The Marvels
# 7                                         Terrifier 2
# 8                                     The Royal Hotel
# 9                                          君たちはどう生きるか
# 10                    Pattie et la colère de Poséidon
# 11  The Hunger Games: The Ballad of Songbirds & Sn...
# 12                                               Wish
# 13                                            Heroico
# 14                                           Napoleon
# 15                                           掃毒3︰人在天涯
# 16                                 El hombre del saco
# 17                                       Megalomaniac
# 18                                         Past Lives
# 19                                          Priscilla
#
#                                              overview  popularity  \
# 0   Recently fired and desperate for work, a troub...    4529.373
# 1   The story of Tim Ballard, a former US governme...     925.953
# 2   Residents of a small rural town discover that ...     566.498
# 3   When Branch’s brother, Floyd, is kidnapped for...     353.878
# 4   A hitman, his boss, an art dealer and a money-...     245.185
# 5   When Reggie is abandoned on the mean city stre...     212.883
# 6   Carol Danvers, aka Captain Marvel, has reclaim...     217.847
# 7   After being resurrected by a sinister entity, ...     173.206
# 8   After running out of money while backpacking i...     127.992
# 9   While the Second World War rages, the teenage ...     119.136
# 10  An adventurous mouse sets off to battle danger...     115.644
# 11  64 years before he becomes the tyrannical pres...     103.504
# 12  Asha, a sharp-witted idealist, makes a wish so...     105.776
# 13  Luis, an 18-year-old boy with Indigenous roots...      93.151
# 14  A personal look at the French military leader’...      93.181
# 15  Hong Kong police agent Cheung (by Aaron Kwok) ...      88.518
# 16  Explores the Spanish origins of the character'...      74.533
# 17  Felix and Martha, the two offspring of legenda...      69.690
# 18  Nora and Hae Sung, two childhood friends, are ...      91.993
# 19  When teenage Priscilla Beaulieu meets Elvis Pr...      63.949
#
#                          poster_path release_date  \
# 0   /A4j8S6moJS2zNtRR8oWF08gRnL5.jpg   2023-10-25
# 1   /qA5kPYZA7FkVvqcEfJRoOy4kpHg.jpg   2023-07-03
# 2   /iQ7G9LhP7NRRIUM4Vlai3eOxBAc.jpg   2023-10-05
# 3   /bkpPTZUdq31UGDovmszsg2CchiI.jpg   2023-10-12
# 4   /qKpdy7N6zX05eisopvvviiTwPxb.jpg   2023-09-14
# 5   /muDaKftykz9Nj1mhRheMdbuNI9Z.jpg   2023-08-17
# 6   /Ag3D9qXjhJ2FUkrlJ0Cv1pgxqYQ.jpg   2023-11-08
# 7   /8gLhu8UFPZfH2Hv11JhTZkb9CVl.jpg   2022-10-06
# 8   /oJwb2PV1LGxDp6Q3lynrjADxOIv.jpg   2023-10-06
# 9   /y9xS5NQTBnFjDoXhSFQeGxlmkoM.jpg   2023-07-14
# 10  /gVPw9gRPsZZhzY6cIXp6h6nep5M.jpg   2023-01-25
# 11  /mBaXZ95R2OxueZhvQbcEWy2DqyO.jpg   2023-11-15
# 12  /8QtDhh8mnGUEyrJsaeb3kYgDRaA.jpg   2023-11-22
# 13  /w0iYqKZYoVmyoX0Av4FdsDiDXWo.jpg   2023-09-21
# 14  /jE5o7y9K6pZtWNNMEw3IdpHuncR.jpg   2023-11-22
# 15  /kPjZsEni0KF0IXGXh0kaxNESdGE.jpg   2023-07-06
# 16  /3EdqlGB2ACpnqsrtKhyacaPhzHK.jpg   2023-08-11
# 17   /bgullymFFblfNaEqRX2j74oTIQ.jpg   2023-09-08
# 18  /k3waqVXSnvCZWfJYNtdamTgTtTA.jpg   2023-06-02
# 19  /3eTAdKJzC8biM52Eii1ghk69bMP.jpg   2023-10-26
#
#                                                 title  video  vote_average  \
# 0                             Five Nights at Freddy's  False         8.292
# 1                                    Sound of Freedom  False         8.100
# 2                                     When Evil Lurks  False         7.587
# 3                                Trolls Band Together  False         6.327
# 4                                       The Kill Room  False         6.200
# 5                                              Strays  False         7.533
# 6                                         The Marvels  False         8.375
# 7                                         Terrifier 2  False         6.793
# 8                                     The Royal Hotel  False         5.864
# 9                               The Boy and the Heron  False         7.500
# 10                                         Epic Tails  False         7.000
# 11  The Hunger Games: The Ballad of Songbirds & Sn...  False         0.000
# 12                                               Wish  False         0.000
# 13                                             Heroic  False         6.300
# 14                                           Napoleon  False         0.000
# 15                  The White Storm 3: Heaven or Hell  False         6.512
# 16                                 El hombre del saco  False         5.700
# 17                                       Megalomaniac  False         6.192
# 18                                         Past Lives  False         7.879
# 19                                          Priscilla  False         6.950
#
#     vote_count
# 0         1485
# 1         1145
# 2          127
# 3           26
# 4           34
# 5          481
# 6            9
# 7         1465
# 8           33
# 9           84
# 10          45
# 11           0
# 12           0
# 13          10
# 14           0
# 15          41
# 16          33
# 17          13
# 18         257
# 19          10

# %%
df["id"]
# Out:
# 0      678512
# 1     1008042
# 2      893723
# 3      958006
# 4      762430
# 5      951491
# 6      466420
# 7     1024773
# 8      507089
# 9     1047041
# 10     354912
# 11     459003
# 12     635910
# 13     496450
# 14     840326
# 15     536437
# 16    1160164
# 17    1093485
# 18     916224
# 19     680133
# Name: id, dtype: int64

# %%
df["id"][2]
# Out:
# 893723

# %%
import requests
id_list = df["id"].tolist()
id_list
base_url = "https://api.themoviedb.org/3/movie/"
language = "us-US"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjN2ZmNDQyZWY5MWQyMGQ1MmJjMDhhOTgzMWFkOGVlZiIsInN1YiI6IjY1MjE2ZjRlYzFmZmJkMDExYjQzNTJlOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.G4CsJ9HQFeIKiIKirMnBbgjnFxo71z-36lqU2hLaUG8"
}
with open("output_IMDB_id.json", "w") as file:
    pass
data_list = []
for movie_id in id_list:
    url = f"{base_url}{movie_id}?language={language}"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
    # Chuyển đổi nội dung JSON thành đối tượng Python
        json_data = json.loads(response.text)
    data_list.append(json_data)
result_dict = {
    "results": data_list
}
# Mở tệp tin để ghi dữ liệu
with open("output_IMDB_id.json", "w") as file:
    json.dump(result_dict, file, indent=4)

# %%
with open("output_IMDB_id.json", "r") as file:
    json_dict = json.load(file)
    formatted_json = json.dumps(json_dict, indent=4)
    print(formatted_json)
# Out:
# {
#     "results": [
#         {
#             "adult": false,
#             "backdrop_path": "/7NRGAtu8E4343NSKwhkgmVRDINw.jpg",
#             "belongs_to_collection": null,
#             "budget": 20000000,
#             "genres": [
#                 {
#                     "id": 27,
#                     "name": "Horror"
#                 },
#                 {
#                     "id": 9648,
#                     "name": "Mystery"
#                 }
#             ],
#             "homepage": "https://www.fivenightsatfreddys.movie",
#             "id": 507089,
#             "imdb_id": "tt4589218",
#             "original_language": "en",
#             "original_title": "Five Nights at Freddy's",
#             "overview": "Recently fired and desperate for work, a troubled young man named Mike agrees to take a position as a night security guard at an abandoned theme restaurant: Freddy Fazbear's Pizzeria. But he soon discovers that nothing at Freddy's is what it seems.",
#             "popularity": 4529.373,
#             "poster_path": "/A4j8S6moJS2zNtRR8oWF08gRnL5.jpg",
#             "production_companies": [
#                 {
#                     "id": 3172,
#                     "logo_path": "/kDedjRZwO8uyFhuHamomOhN6fzG.png",
#                     "name": "Blumhouse Productions",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 211144,
#                     "logo_path": null,
#                     "name": "Scott Cawthon Productions",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-10-25",
#             "revenue": 152000000,
#             "runtime": 110,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "Can you survive five nights?",
#             "title": "Five Nights at Freddy's",
#             "video": false,
#             "vote_average": 8.296,
#             "vote_count": 1481
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/pA3vdhadJPxF5GA1uo8OPTiNQDT.jpg",
#             "belongs_to_collection": null,
#             "budget": 14500000,
#             "genres": [
#                 {
#                     "id": 28,
#                     "name": "Action"
#                 },
#                 {
#                     "id": 18,
#                     "name": "Drama"
#                 }
#             ],
#             "homepage": "https://www.soundoffreedommovie.com/",
#             "id": 678512,
#             "imdb_id": "tt7599146",
#             "original_language": "en",
#             "original_title": "Sound of Freedom",
#             "overview": "The story of Tim Ballard, a former US government agent, who quits his job in order to devote his life to rescuing children from global sex traffickers.",
#             "popularity": 925.953,
#             "poster_path": "/qA5kPYZA7FkVvqcEfJRoOy4kpHg.jpg",
#             "production_companies": [
#                 {
#                     "id": 90508,
#                     "logo_path": null,
#                     "name": "Santa Fe Films",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-07-03",
#             "revenue": 239366545,
#             "runtime": 131,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 },
#                 {
#                     "english_name": "Spanish",
#                     "iso_639_1": "es",
#                     "name": "Espa\u00f1ol"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "Fight for the light. Silence the darkness.",
#             "title": "Sound of Freedom",
#             "video": false,
#             "vote_average": 8.126,
#             "vote_count": 1147
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/mv8M0PqQYicndU7TGgBAHrI4uUo.jpg",
#             "belongs_to_collection": null,
#             "budget": 0,
#             "genres": [
#                 {
#                     "id": 27,
#                     "name": "Horror"
#                 },
#                 {
#                     "id": 53,
#                     "name": "Thriller"
#                 }
#             ],
#             "homepage": "",
#             "id": 744857,
#             "imdb_id": "tt16300962",
#             "original_language": "es",
#             "original_title": "Cuando acecha la maldad",
#             "overview": "Residents of a small rural town discover that a demon is about to be born among them. They desperately try to escape before the evil is born, but it may be too late.",
#             "popularity": 566.498,
#             "poster_path": "/iQ7G9LhP7NRRIUM4Vlai3eOxBAc.jpg",
#             "production_companies": [
#                 {
#                     "id": 28912,
#                     "logo_path": "/jMjy9m6msnTVMEqrM22ULXJa45Y.png",
#                     "name": "Machaco Films",
#                     "origin_country": "AR"
#                 },
#                 {
#                     "id": 165642,
#                     "logo_path": null,
#                     "name": "La Puerta Roja",
#                     "origin_country": ""
#                 },
#                 {
#                     "id": 135436,
#                     "logo_path": "/4B3xLSierSSePQkwtiMAT3YDpJn.png",
#                     "name": "Aramos Cine",
#                     "origin_country": "AR"
#                 },
#                 {
#                     "id": 53766,
#                     "logo_path": "/bxhF6lhto38us6TVa3dba79HtdW.png",
#                     "name": "Mutante Cine",
#                     "origin_country": "UY"
#                 },
#                 {
#                     "id": 142877,
#                     "logo_path": "/c0Qhy9uvdXfvAZQ9e8GnT5Nb75m.png",
#                     "name": "Shudder",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 102626,
#                     "logo_path": "/hejnYBBwutw4U2dA6LGfMArjya0.png",
#                     "name": "Cine Argentino",
#                     "origin_country": "AR"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "AR",
#                     "name": "Argentina"
#                 },
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 },
#                 {
#                     "iso_3166_1": "UY",
#                     "name": "Uruguay"
#                 }
#             ],
#             "release_date": "2023-10-05",
#             "revenue": 0,
#             "runtime": 99,
#             "spoken_languages": [
#                 {
#                     "english_name": "Spanish",
#                     "iso_639_1": "es",
#                     "name": "Espa\u00f1ol"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "There's no point in praying.",
#             "title": "When Evil Lurks",
#             "video": false,
#             "vote_average": 7.59,
#             "vote_count": 128
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/45zVtZx6Tzx3RKeDziK25K9geFf.jpg",
#             "belongs_to_collection": {
#                 "id": 489724,
#                 "name": "The Trolls Collection",
#                 "poster_path": "/i4aII37O184x7K3dC7fpF9CAfS4.jpg",
#                 "backdrop_path": "/xtgonS6wcxK5RfnWWohYZF3mhjM.jpg"
#             },
#             "budget": 0,
#             "genres": [
#                 {
#                     "id": 16,
#                     "name": "Animation"
#                 },
#                 {
#                     "id": 10751,
#                     "name": "Family"
#                 },
#                 {
#                     "id": 10402,
#                     "name": "Music"
#                 },
#                 {
#                     "id": 14,
#                     "name": "Fantasy"
#                 },
#                 {
#                     "id": 35,
#                     "name": "Comedy"
#                 }
#             ],
#             "homepage": "https://www.dreamworks.com/movies/trolls-band-together",
#             "id": 901362,
#             "imdb_id": "tt14362112",
#             "original_language": "en",
#             "original_title": "Trolls Band Together",
#             "overview": "When Branch\u2019s brother, Floyd, is kidnapped for his musical talents by a pair of nefarious pop-star villains, Branch and Poppy embark on a harrowing and emotional journey to reunite the other brothers and rescue Floyd from a fate even worse than pop-culture obscurity.",
#             "popularity": 353.878,
#             "poster_path": "/bkpPTZUdq31UGDovmszsg2CchiI.jpg",
#             "production_companies": [
#                 {
#                     "id": 521,
#                     "logo_path": "/kP7t6RwGz2AvvTkvnI1uteEwHet.png",
#                     "name": "DreamWorks Animation",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 33,
#                     "logo_path": "/8lvHyhjr8oUKOOy2dKXoALWKdp0.png",
#                     "name": "Universal Pictures",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-10-12",
#             "revenue": 38200000,
#             "runtime": 92,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "There are some new trolls on the block.",
#             "title": "Trolls Band Together",
#             "video": false,
#             "vote_average": 6.327,
#             "vote_count": 26
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/xHqTnPtpd9Qd7R0fVtoqxZYM67Q.jpg",
#             "belongs_to_collection": null,
#             "budget": 50000000,
#             "genres": [
#                 {
#                     "id": 80,
#                     "name": "Crime"
#                 },
#                 {
#                     "id": 53,
#                     "name": "Thriller"
#                 },
#                 {
#                     "id": 28,
#                     "name": "Action"
#                 }
#             ],
#             "homepage": "https://www.bluefoxentertainment.com/films/the-kill-room",
#             "id": 958006,
#             "imdb_id": "tt11908172",
#             "original_language": "en",
#             "original_title": "The Kill Room",
#             "overview": "A hitman, his boss, an art dealer and a money-laundering scheme that accidentally turns the assassin into an overnight avant-garde sensation, one that forces her to play the art world against the underworld.",
#             "popularity": 245.185,
#             "poster_path": "/qKpdy7N6zX05eisopvvviiTwPxb.jpg",
#             "production_companies": [
#                 {
#                     "id": 75355,
#                     "logo_path": "/avj80RsunqwDbOS6oLp4plRE5UQ.png",
#                     "name": "Yale Productions",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 87705,
#                     "logo_path": null,
#                     "name": "Idiot Savant Pictures",
#                     "origin_country": ""
#                 },
#                 {
#                     "id": 46225,
#                     "logo_path": null,
#                     "name": "Untitled Entertainment",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 168282,
#                     "logo_path": "/mO481qJ4RmFhPtv36qIbUbGc0LE.png",
#                     "name": "Such Content",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 72316,
#                     "logo_path": null,
#                     "name": "BK Studios",
#                     "origin_country": "GB"
#                 },
#                 {
#                     "id": 121204,
#                     "logo_path": "/vbtvY4IxgUZk713rkmoTO4MHIac.png",
#                     "name": "BondIt Media Capital",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 5056,
#                     "logo_path": "/583ITs4w9sK31FnJwKiRwapTpzb.png",
#                     "name": "Head Gear Films",
#                     "origin_country": "GB"
#                 },
#                 {
#                     "id": 25954,
#                     "logo_path": "/oga9DS7GZGbZ0iZ4JFuVTBMBv1C.png",
#                     "name": "Metrol Technology",
#                     "origin_country": "GB"
#                 },
#                 {
#                     "id": 195600,
#                     "logo_path": "/raR05O2dHolS08mMKRKHEPVl59i.png",
#                     "name": "Slated",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 205513,
#                     "logo_path": "/7INId4OALujmK9o23QFJFyVa1fv.png",
#                     "name": "SuperNova Capital",
#                     "origin_country": "GB"
#                 },
#                 {
#                     "id": 205514,
#                     "logo_path": null,
#                     "name": "Complex Corp",
#                     "origin_country": ""
#                 },
#                 {
#                     "id": 205516,
#                     "logo_path": "/tx6QPkhCXKhOr18hAhPGvT4hZDE.png",
#                     "name": "Great Escape",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-09-14",
#             "revenue": 476375,
#             "runtime": 98,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "Crime is an art form.",
#             "title": "The Kill Room",
#             "video": false,
#             "vote_average": 6.2,
#             "vote_count": 34
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/mfm4srsPALxaeOMFFFJ0drXTyXy.jpg",
#             "belongs_to_collection": null,
#             "budget": 46000000,
#             "genres": [
#                 {
#                     "id": 35,
#                     "name": "Comedy"
#                 },
#                 {
#                     "id": 12,
#                     "name": "Adventure"
#                 }
#             ],
#             "homepage": "https://www.uphe.com/movies/strays-2023",
#             "id": 912908,
#             "imdb_id": "tt15153532",
#             "original_language": "en",
#             "original_title": "Strays",
#             "overview": "When Reggie is abandoned on the mean city streets by his lowlife owner, Doug, Reggie is certain that his beloved owner would never leave him on purpose. But once Reggie falls in with Bug, a fast-talking, foul-mouthed stray who loves his freedom and believes that owners are for suckers, Reggie finally realizes he was in a toxic relationship and begins to see Doug for the heartless sleazeball that he is.",
#             "popularity": 212.883,
#             "poster_path": "/muDaKftykz9Nj1mhRheMdbuNI9Z.jpg",
#             "production_companies": [
#                 {
#                     "id": 33,
#                     "logo_path": "/8lvHyhjr8oUKOOy2dKXoALWKdp0.png",
#                     "name": "Universal Pictures",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 77973,
#                     "logo_path": "/9y5lW86HnxKUZOFencYk3TIIRCM.png",
#                     "name": "Lord Miller",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 123244,
#                     "logo_path": "/7eH1Y4RIuontJJXVmmSRrNUMZhU.png",
#                     "name": "PictureStart",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 162500,
#                     "logo_path": "/onZtHqDNrJJl4QoEmMvakzCqJcS.png",
#                     "name": "Rabbit Hole Productions",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-08-17",
#             "revenue": 32000000,
#             "runtime": 93,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "Go fetch yourself.",
#             "title": "Strays",
#             "video": false,
#             "vote_average": 7.533,
#             "vote_count": 481
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/5vHvR0fEVuypYZ7TOJTQWPfs3tI.jpg",
#             "belongs_to_collection": {
#                 "id": 623911,
#                 "name": "Captain Marvel Collection",
#                 "poster_path": "/mHiMmryCureDvoAOlGP6o3oXT8Y.jpg",
#                 "backdrop_path": "/ubZUKycnQldt2umj0bPD2VwXDJM.jpg"
#             },
#             "budget": 274800000,
#             "genres": [
#                 {
#                     "id": 28,
#                     "name": "Action"
#                 },
#                 {
#                     "id": 12,
#                     "name": "Adventure"
#                 },
#                 {
#                     "id": 878,
#                     "name": "Science Fiction"
#                 }
#             ],
#             "homepage": "https://www.marvel.com/movies/the-marvels",
#             "id": 609681,
#             "imdb_id": "tt10676048",
#             "original_language": "en",
#             "original_title": "The Marvels",
#             "overview": "Carol Danvers, aka Captain Marvel, has reclaimed her identity from the tyrannical Kree and taken revenge on the Supreme Intelligence. But unintended consequences see Carol shouldering the burden of a destabilized universe. When her duties send her to an anomalous wormhole linked to a Kree revolutionary, her powers become entangled with that of Jersey City super-fan Kamala Khan, aka Ms. Marvel, and Carol\u2019s estranged niece, now S.A.B.E.R. astronaut Captain Monica Rambeau. Together, this unlikely trio must team up and learn to work in concert to save the universe.",
#             "popularity": 217.847,
#             "poster_path": "/Ag3D9qXjhJ2FUkrlJ0Cv1pgxqYQ.jpg",
#             "production_companies": [
#                 {
#                     "id": 420,
#                     "logo_path": "/hUzeosd33nzE5MCNsZxCGEKTXaQ.png",
#                     "name": "Marvel Studios",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 176762,
#                     "logo_path": null,
#                     "name": "Kevin Feige Productions",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-11-08",
#             "revenue": 0,
#             "runtime": 105,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "Higher. Further. Faster. Together.",
#             "title": "The Marvels",
#             "video": false,
#             "vote_average": 8.4,
#             "vote_count": 9
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/cRdA9xjHBbobw4LJFsQ3j1CgpVq.jpg",
#             "belongs_to_collection": {
#                 "id": 727761,
#                 "name": "Terrifier Collection",
#                 "poster_path": "/fTDmbVPqUfeIMKM1ThLHSquwMsm.jpg",
#                 "backdrop_path": "/rADvCVtvgy0s6MoAzB9OwKieRss.jpg"
#             },
#             "budget": 250000,
#             "genres": [
#                 {
#                     "id": 27,
#                     "name": "Horror"
#                 },
#                 {
#                     "id": 53,
#                     "name": "Thriller"
#                 }
#             ],
#             "homepage": "http://www.terrifier2themovie.com/",
#             "id": 663712,
#             "imdb_id": "tt10403420",
#             "original_language": "en",
#             "original_title": "Terrifier 2",
#             "overview": "After being resurrected by a sinister entity, Art the Clown returns to Miles County where he must hunt down and destroy a teenage girl and her younger brother on Halloween night.  As the body count rises, the siblings fight to stay alive while uncovering the true nature of Art's evil intent.",
#             "popularity": 173.206,
#             "poster_path": "/8gLhu8UFPZfH2Hv11JhTZkb9CVl.jpg",
#             "production_companies": [
#                 {
#                     "id": 84591,
#                     "logo_path": null,
#                     "name": "Dark Age Cinema",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 114220,
#                     "logo_path": null,
#                     "name": "Fuzz on the Lens Productions",
#                     "origin_country": ""
#                 },
#                 {
#                     "id": 15157,
#                     "logo_path": "/yezzLb9RbKNtQUsyYySAqC9TQr7.png",
#                     "name": "Bloody Disgusting",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2022-10-06",
#             "revenue": 15100000,
#             "runtime": 138,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "Who's laughing now?",
#             "title": "Terrifier 2",
#             "video": false,
#             "vote_average": 6.793,
#             "vote_count": 1465
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/cofs7Y72FkRjALbOOOz8q7Uty6h.jpg",
#             "belongs_to_collection": null,
#             "budget": 91,
#             "genres": [
#                 {
#                     "id": 18,
#                     "name": "Drama"
#                 },
#                 {
#                     "id": 53,
#                     "name": "Thriller"
#                 }
#             ],
#             "homepage": "",
#             "id": 944952,
#             "imdb_id": "tt18363072",
#             "original_language": "en",
#             "original_title": "The Royal Hotel",
#             "overview": "After running out of money while backpacking in a tiny, male-dominated town in the Australian outback, two friends resort to a working holiday at the Royal Hotel. When the locals behavior starts crossing the line, the girls find themselves trapped in an unnerving situation that grows rapidly out of their control.",
#             "popularity": 127.992,
#             "poster_path": "/oJwb2PV1LGxDp6Q3lynrjADxOIv.jpg",
#             "production_companies": [
#                 {
#                     "id": 7217,
#                     "logo_path": "/vFbexaF70wSMUHRA6Fy6UcuA1ju.png",
#                     "name": "See-Saw Films",
#                     "origin_country": "GB"
#                 },
#                 {
#                     "id": 12128,
#                     "logo_path": "/gqN7u1StkZGllkQUKqiLODLRXHb.png",
#                     "name": "Scarlett Pictures",
#                     "origin_country": "AU"
#                 },
#                 {
#                     "id": 7584,
#                     "logo_path": "/eGkfvvyf4fJTvBUR1xt1669IPA3.png",
#                     "name": "Screen Australia",
#                     "origin_country": "AU"
#                 },
#                 {
#                     "id": 2806,
#                     "logo_path": "/vxOhCbpsRBh10m6LZ3HyImTYpPY.png",
#                     "name": "South Australian Film Corporation",
#                     "origin_country": "AU"
#                 },
#                 {
#                     "id": 10951,
#                     "logo_path": "/jxfMNlkvI3GxnS41xCSOLD7goVb.png",
#                     "name": "Screen NSW",
#                     "origin_country": "AU"
#                 },
#                 {
#                     "id": 2395,
#                     "logo_path": "/pZz4qs03FtP6UGtZ3hjQ6qimcwi.png",
#                     "name": "HanWay Films",
#                     "origin_country": "GB"
#                 },
#                 {
#                     "id": 159766,
#                     "logo_path": "/A6yBN3mIr9S0tOtahRCx8rJtwuY.png",
#                     "name": "Cross City Films",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 208048,
#                     "logo_path": null,
#                     "name": "Alma Margo",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "AU",
#                     "name": "Australia"
#                 },
#                 {
#                     "iso_3166_1": "GB",
#                     "name": "United Kingdom"
#                 },
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-10-06",
#             "revenue": 755034,
#             "runtime": 91,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 },
#                 {
#                     "english_name": "Swedish",
#                     "iso_639_1": "sv",
#                     "name": "svenska"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "A fun adventure is all they wanted.",
#             "title": "The Royal Hotel",
#             "video": false,
#             "vote_average": 5.864,
#             "vote_count": 33
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/a0GM57AnJtNi7lMOCamniiyV10W.jpg",
#             "belongs_to_collection": null,
#             "budget": 0,
#             "genres": [
#                 {
#                     "id": 16,
#                     "name": "Animation"
#                 },
#                 {
#                     "id": 12,
#                     "name": "Adventure"
#                 },
#                 {
#                     "id": 14,
#                     "name": "Fantasy"
#                 },
#                 {
#                     "id": 18,
#                     "name": "Drama"
#                 }
#             ],
#             "homepage": "https://gkids.com/films/the-boy-and-the-heron/",
#             "id": 508883,
#             "imdb_id": "tt6587046",
#             "original_language": "ja",
#             "original_title": "\u541b\u305f\u3061\u306f\u3069\u3046\u751f\u304d\u308b\u304b",
#             "overview": "While the Second World War rages, the teenage Mahito, haunted by his mother's tragic death, is relocated from Tokyo to the serene rural home of his new stepmother Natsuko, a woman who bears a striking resemblance to the boy's mother. As he tries to adjust, this strange new world grows even stranger following the appearance of a persistent gray heron, who perplexes and bedevils Mahito, dubbing him the \"long-awaited one.\"",
#             "popularity": 119.136,
#             "poster_path": "/y9xS5NQTBnFjDoXhSFQeGxlmkoM.jpg",
#             "production_companies": [
#                 {
#                     "id": 10342,
#                     "logo_path": "/eS79pslnoKbWg7t3PMA9ayl0bGs.png",
#                     "name": "Studio Ghibli",
#                     "origin_country": "JP"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "JP",
#                     "name": "Japan"
#                 }
#             ],
#             "release_date": "2023-07-14",
#             "revenue": 55800000,
#             "runtime": 124,
#             "spoken_languages": [
#                 {
#                     "english_name": "Japanese",
#                     "iso_639_1": "ja",
#                     "name": "\u65e5\u672c\u8a9e"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "",
#             "title": "The Boy and the Heron",
#             "video": false,
#             "vote_average": 7.494,
#             "vote_count": 85
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/qZOuoBoKCDLSm1EvYz2eBub8Cto.jpg",
#             "belongs_to_collection": null,
#             "budget": 0,
#             "genres": [
#                 {
#                     "id": 16,
#                     "name": "Animation"
#                 },
#                 {
#                     "id": 12,
#                     "name": "Adventure"
#                 },
#                 {
#                     "id": 14,
#                     "name": "Fantasy"
#                 },
#                 {
#                     "id": 10751,
#                     "name": "Family"
#                 }
#             ],
#             "homepage": "",
#             "id": 939338,
#             "imdb_id": "tt22360682",
#             "original_language": "fr",
#             "original_title": "Pattie et la col\u00e8re de Pos\u00e9idon",
#             "overview": "An adventurous mouse sets off to battle dangerous creatures in Ancient Greece, including Poseidon.",
#             "popularity": 115.644,
#             "poster_path": "/gVPw9gRPsZZhzY6cIXp6h6nep5M.jpg",
#             "production_companies": [
#                 {
#                     "id": 28792,
#                     "logo_path": null,
#                     "name": "TAT Productions",
#                     "origin_country": "FR"
#                 },
#                 {
#                     "id": 49755,
#                     "logo_path": "/iom7Z8e1dzoTfCvwq8F4bJvbeIJ.png",
#                     "name": "Apollo Films",
#                     "origin_country": "FR"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "FR",
#                     "name": "France"
#                 }
#             ],
#             "release_date": "2023-01-25",
#             "revenue": 4834952,
#             "runtime": 95,
#             "spoken_languages": [
#                 {
#                     "english_name": "Danish",
#                     "iso_639_1": "da",
#                     "name": "Dansk"
#                 },
#                 {
#                     "english_name": "Finnish",
#                     "iso_639_1": "fi",
#                     "name": "suomi"
#                 },
#                 {
#                     "english_name": "French",
#                     "iso_639_1": "fr",
#                     "name": "Fran\u00e7ais"
#                 },
#                 {
#                     "english_name": "Norwegian",
#                     "iso_639_1": "no",
#                     "name": "Norsk"
#                 },
#                 {
#                     "english_name": "Swedish",
#                     "iso_639_1": "sv",
#                     "name": "svenska"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "Small heroes, big adventure.",
#             "title": "Epic Tails",
#             "video": false,
#             "vote_average": 7.0,
#             "vote_count": 45
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/hon92J1oqdrTwcGHXG64G2bXqrJ.jpg",
#             "belongs_to_collection": null,
#             "budget": 100000000,
#             "genres": [
#                 {
#                     "id": 28,
#                     "name": "Action"
#                 },
#                 {
#                     "id": 12,
#                     "name": "Adventure"
#                 },
#                 {
#                     "id": 878,
#                     "name": "Science Fiction"
#                 }
#             ],
#             "homepage": "https://hungergames.movie",
#             "id": 695721,
#             "imdb_id": "tt10545296",
#             "original_language": "en",
#             "original_title": "The Hunger Games: The Ballad of Songbirds & Snakes",
#             "overview": "64 years before he becomes the tyrannical president of Panem, Coriolanus Snow sees a chance for a change in fortunes when he mentors Lucy Gray Baird, the female tribute from District 12.",
#             "popularity": 103.504,
#             "poster_path": "/mBaXZ95R2OxueZhvQbcEWy2DqyO.jpg",
#             "production_companies": [
#                 {
#                     "id": 1632,
#                     "logo_path": "/cisLn1YAUuptXVBa0xjq7ST9cH0.png",
#                     "name": "Lionsgate",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 5420,
#                     "logo_path": "/dlW4Kh5dNieKNURnymsu57y6fMf.png",
#                     "name": "Color Force",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 17393,
#                     "logo_path": "/k28sCof6kheeOicLqL6EXX2GHov.png",
#                     "name": "Good Universe",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-11-15",
#             "revenue": 0,
#             "runtime": 157,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 }
#             ],
#             "status": "Post Production",
#             "tagline": "Everyone hungers for something.",
#             "title": "The Hunger Games: The Ballad of Songbirds & Snakes",
#             "video": false,
#             "vote_average": 0.0,
#             "vote_count": 0
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/mEcCz4Nzw57wJIXo6g69q9NUQih.jpg",
#             "belongs_to_collection": null,
#             "budget": 200000000,
#             "genres": [
#                 {
#                     "id": 16,
#                     "name": "Animation"
#                 },
#                 {
#                     "id": 10751,
#                     "name": "Family"
#                 },
#                 {
#                     "id": 14,
#                     "name": "Fantasy"
#                 },
#                 {
#                     "id": 12,
#                     "name": "Adventure"
#                 }
#             ],
#             "homepage": "https://movies.disney.com/wish",
#             "id": 1022796,
#             "imdb_id": "tt11304740",
#             "original_language": "en",
#             "original_title": "Wish",
#             "overview": "Asha, a sharp-witted idealist, makes a wish so powerful that it is answered by a cosmic force\u2014a little ball of boundless energy called Star. Together, Asha and Star confront a most formidable foe\u2014the ruler of Rosas, King Magnifico\u2014to save her community and prove that when the will of one courageous human connects with the magic of the stars, wondrous things can happen.",
#             "popularity": 105.776,
#             "poster_path": "/8QtDhh8mnGUEyrJsaeb3kYgDRaA.jpg",
#             "production_companies": [
#                 {
#                     "id": 6125,
#                     "logo_path": "/tzsMJBJZINu7GHzrpYzpReWhh66.png",
#                     "name": "Walt Disney Animation Studios",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 2,
#                     "logo_path": "/wdrCwmRnLFJhEoH8GSfymY85KHT.png",
#                     "name": "Walt Disney Pictures",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-11-22",
#             "revenue": 0,
#             "runtime": 92,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 }
#             ],
#             "status": "Post Production",
#             "tagline": "Be careful what you wish for.",
#             "title": "Wish",
#             "video": false,
#             "vote_average": 0.0,
#             "vote_count": 0
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/8g9ZdvHX6jszRY71aVtpRUmHQzJ.jpg",
#             "belongs_to_collection": null,
#             "budget": 0,
#             "genres": [
#                 {
#                     "id": 18,
#                     "name": "Drama"
#                 },
#                 {
#                     "id": 53,
#                     "name": "Thriller"
#                 }
#             ],
#             "homepage": "",
#             "id": 958182,
#             "imdb_id": "tt24079846",
#             "original_language": "es",
#             "original_title": "Heroico",
#             "overview": "Luis, an 18-year-old boy with Indigenous roots, enters the Heroic Military College in hopes of ensuring a better future. There, he encounters a rigid and institutionally violent system designed to turn him into a perfect soldier.",
#             "popularity": 93.151,
#             "poster_path": "/w0iYqKZYoVmyoX0Av4FdsDiDXWo.jpg",
#             "production_companies": [
#                 {
#                     "id": 2801,
#                     "logo_path": "/bswb1PLLsKDUXMLgy42bZtCtIde.png",
#                     "name": "Film i V\u00e4st",
#                     "origin_country": "SE"
#                 },
#                 {
#                     "id": 33384,
#                     "logo_path": "/bLV4TDUm4H6UjFSr3d1oidO4rhy.png",
#                     "name": "Common Ground Pictures",
#                     "origin_country": "SE"
#                 },
#                 {
#                     "id": 17116,
#                     "logo_path": null,
#                     "name": "TEOREMA",
#                     "origin_country": "MX"
#                 },
#                 {
#                     "id": 191621,
#                     "logo_path": "/f9Vkl26ue8YdcnSxeIGasY1s1R5.png",
#                     "name": "Filmadora",
#                     "origin_country": "MX"
#                 },
#                 {
#                     "id": 148503,
#                     "logo_path": "/9YEQ1qThOSJshp11831hMNzH48P.png",
#                     "name": "CTT Exp & Rentals",
#                     "origin_country": "MX"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "MX",
#                     "name": "Mexico"
#                 },
#                 {
#                     "iso_3166_1": "SE",
#                     "name": "Sweden"
#                 }
#             ],
#             "release_date": "2023-09-21",
#             "revenue": 0,
#             "runtime": 88,
#             "spoken_languages": [
#                 {
#                     "english_name": "Spanish",
#                     "iso_639_1": "es",
#                     "name": "Espa\u00f1ol"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "There are no rights here, not even humans.",
#             "title": "Heroic",
#             "video": false,
#             "vote_average": 6.3,
#             "vote_count": 10
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/wOYDsD7WIKsz5DtrnjsvCcEyFJa.jpg",
#             "belongs_to_collection": null,
#             "budget": 0,
#             "genres": [
#                 {
#                     "id": 36,
#                     "name": "History"
#                 },
#                 {
#                     "id": 18,
#                     "name": "Drama"
#                 },
#                 {
#                     "id": 10752,
#                     "name": "War"
#                 }
#             ],
#             "homepage": "https://www.napoleon.movie",
#             "id": 753342,
#             "imdb_id": "tt13287846",
#             "original_language": "en",
#             "original_title": "Napoleon",
#             "overview": "A personal look at the French military leader\u2019s origins and swift, ruthless climb to emperor, viewed through the prism of Napoleon\u2019s addictive, volatile relationship with his wife and one true love, Josephine.",
#             "popularity": 93.181,
#             "poster_path": "/jE5o7y9K6pZtWNNMEw3IdpHuncR.jpg",
#             "production_companies": [
#                 {
#                     "id": 1645,
#                     "logo_path": "/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png",
#                     "name": "Scott Free Productions",
#                     "origin_country": "GB"
#                 },
#                 {
#                     "id": 19108,
#                     "logo_path": "/jWhpxFZd02PbcFtUSiCraifRZTC.png",
#                     "name": "Latina Pictures",
#                     "origin_country": "MT"
#                 },
#                 {
#                     "id": 194232,
#                     "logo_path": "/oE7H93u8sy5vvW5EH3fpCp68vvB.png",
#                     "name": "Apple Studios",
#                     "origin_country": "US"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "MT",
#                     "name": "Malta"
#                 },
#                 {
#                     "iso_3166_1": "GB",
#                     "name": "United Kingdom"
#                 },
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-11-22",
#             "revenue": 0,
#             "runtime": 157,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 },
#                 {
#                     "english_name": "French",
#                     "iso_639_1": "fr",
#                     "name": "Fran\u00e7ais"
#                 }
#             ],
#             "status": "Post Production",
#             "tagline": "He came from nothing. He conquered everything.",
#             "title": "Napoleon",
#             "video": false,
#             "vote_average": 0.0,
#             "vote_count": 0
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/5ut2rC5H1YE0GnNPpl1csnNvqum.jpg",
#             "belongs_to_collection": {
#                 "id": 644309,
#                 "name": "The White Storm Collection",
#                 "poster_path": "/w9vFtQwe3SuGK6MGc0zXprZfDsg.jpg",
#                 "backdrop_path": "/6wBeEzQ3fSXsQtbPck2EVtWLWgD.jpg"
#             },
#             "budget": 0,
#             "genres": [
#                 {
#                     "id": 28,
#                     "name": "Action"
#                 },
#                 {
#                     "id": 18,
#                     "name": "Drama"
#                 },
#                 {
#                     "id": 80,
#                     "name": "Crime"
#                 }
#             ],
#             "homepage": "",
#             "id": 1093485,
#             "imdb_id": "tt26929966",
#             "original_language": "cn",
#             "original_title": "\u6383\u6bd23\ufe30\u4eba\u5728\u5929\u6daf",
#             "overview": "Hong Kong police agent Cheung (by Aaron Kwok) works undercover in Kang\u2019s (by Sean Lau) drug cartel, while another undercover cop Au (by Louis Koo) successfully earns their trust in an incident, a brotherly-bond is built among the three. After the Police busts the syndicate in Hong Kong, Kang subsequently hides away in the Golden Triangle, by chance he receives a tip-off about the betrayal within his circle of trust\u2026",
#             "popularity": 88.518,
#             "poster_path": "/kPjZsEni0KF0IXGXh0kaxNESdGE.jpg",
#             "production_companies": [
#                 {
#                     "id": 20543,
#                     "logo_path": null,
#                     "name": "Universe Entertainment",
#                     "origin_country": "HK"
#                 },
#                 {
#                     "id": 194625,
#                     "logo_path": null,
#                     "name": "AMTD Digital",
#                     "origin_country": ""
#                 },
#                 {
#                     "id": 56157,
#                     "logo_path": null,
#                     "name": "Hero Films",
#                     "origin_country": ""
#                 },
#                 {
#                     "id": 131587,
#                     "logo_path": null,
#                     "name": "Lian Ray Pictures",
#                     "origin_country": "CN"
#                 },
#                 {
#                     "id": 55902,
#                     "logo_path": null,
#                     "name": "Sun Entertainment Culture",
#                     "origin_country": ""
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "CN",
#                     "name": "China"
#                 },
#                 {
#                     "iso_3166_1": "HK",
#                     "name": "Hong Kong"
#                 }
#             ],
#             "release_date": "2023-07-06",
#             "revenue": 0,
#             "runtime": 125,
#             "spoken_languages": [
#                 {
#                     "english_name": "Cantonese",
#                     "iso_639_1": "cn",
#                     "name": "\u5e7f\u5dde\u8bdd / \u5ee3\u5dde\u8a71"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "",
#             "title": "The White Storm 3: Heaven or Hell",
#             "video": false,
#             "vote_average": 6.512,
#             "vote_count": 41
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/eXX9PqCgbTVYnnlbGuAz7Lk4E86.jpg",
#             "belongs_to_collection": null,
#             "budget": 0,
#             "genres": [
#                 {
#                     "id": 27,
#                     "name": "Horror"
#                 },
#                 {
#                     "id": 12,
#                     "name": "Adventure"
#                 }
#             ],
#             "homepage": "",
#             "id": 1145851,
#             "imdb_id": "tt22050310",
#             "original_language": "es",
#             "original_title": "El hombre del saco",
#             "overview": "Explores the Spanish origins of the character's story, where he is a tuberculosis patient from Almeria who will do anything to get well, even consuming the blood of the kids he kidnaps in a sack.",
#             "popularity": 74.533,
#             "poster_path": "/3EdqlGB2ACpnqsrtKhyacaPhzHK.jpg",
#             "production_companies": [
#                 {
#                     "id": 149886,
#                     "logo_path": "/oDG7mNqzGZGRI8Q4qIAPOS0wdh4.png",
#                     "name": "Esto Tambi\u00e9n Pasar\u00e1",
#                     "origin_country": "ES"
#                 },
#                 {
#                     "id": 29240,
#                     "logo_path": "/qz14qTCqR1KdkOGFsP1DQ4LcmI3.png",
#                     "name": "Mother Superior",
#                     "origin_country": "UY"
#                 },
#                 {
#                     "id": 91991,
#                     "logo_path": "/ngEpBkH7nkFfyCCtvGhhIzPS1xF.png",
#                     "name": "Bowfinger",
#                     "origin_country": "ES"
#                 },
#                 {
#                     "id": 96809,
#                     "logo_path": "/wIXZQfxz4mm3Ag0ieXDAf2L2C9f.png",
#                     "name": "BTF Media",
#                     "origin_country": "MX"
#                 },
#                 {
#                     "id": 80408,
#                     "logo_path": "/e2LblDStah74O4c9E6o1U0qv0Oa.png",
#                     "name": "The Glow",
#                     "origin_country": "ES"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "ES",
#                     "name": "Spain"
#                 },
#                 {
#                     "iso_3166_1": "UY",
#                     "name": "Uruguay"
#                 }
#             ],
#             "release_date": "2023-08-11",
#             "revenue": 0,
#             "runtime": 0,
#             "spoken_languages": [
#                 {
#                     "english_name": "Spanish",
#                     "iso_639_1": "es",
#                     "name": "Espa\u00f1ol"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "",
#             "title": "El hombre del saco",
#             "video": false,
#             "vote_average": 5.7,
#             "vote_count": 33
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/drfl2eWipiibW3u3Ybx9HQ8VgIn.jpg",
#             "belongs_to_collection": null,
#             "budget": 0,
#             "genres": [
#                 {
#                     "id": 27,
#                     "name": "Horror"
#                 },
#                 {
#                     "id": 9648,
#                     "name": "Mystery"
#                 },
#                 {
#                     "id": 53,
#                     "name": "Thriller"
#                 }
#             ],
#             "homepage": "",
#             "id": 841742,
#             "imdb_id": "tt10916810",
#             "original_language": "fr",
#             "original_title": "Megalomaniac",
#             "overview": "Felix and Martha, the two offspring of legendary serial murderer The Skinner of Mons, grapple with the grotesque legacy bequeathed to them. While Martha works a menial janitorial job, Felix continues his father's reign of terror. But following a brutal attack at work, Martha quickly descends into madness, finding she must come to terms with the infamous blood that flows through her veins.",
#             "popularity": 69.69,
#             "poster_path": "/bgullymFFblfNaEqRX2j74oTIQ.jpg",
#             "production_companies": [
#                 {
#                     "id": 78939,
#                     "logo_path": null,
#                     "name": "Les Films du Carr\u00e9",
#                     "origin_country": ""
#                 },
#                 {
#                     "id": 19037,
#                     "logo_path": "/tceh2aAORA5JxIZSLQ1GkzTBZDL.png",
#                     "name": "uMedia",
#                     "origin_country": "BE"
#                 },
#                 {
#                     "id": 22127,
#                     "logo_path": "/lgkXXc4hyHH6WqVMJVUFrhFIjm5.png",
#                     "name": "uFund",
#                     "origin_country": "BE"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "BE",
#                     "name": "Belgium"
#                 }
#             ],
#             "release_date": "2023-09-08",
#             "revenue": 0,
#             "runtime": 100,
#             "spoken_languages": [
#                 {
#                     "english_name": "French",
#                     "iso_639_1": "fr",
#                     "name": "Fran\u00e7ais"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "",
#             "title": "Megalomaniac",
#             "video": false,
#             "vote_average": 6.192,
#             "vote_count": 13
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/rron9HAuS9s7zBF8iCX1tsafxUo.jpg",
#             "belongs_to_collection": null,
#             "budget": 12000000,
#             "genres": [
#                 {
#                     "id": 18,
#                     "name": "Drama"
#                 },
#                 {
#                     "id": 10749,
#                     "name": "Romance"
#                 }
#             ],
#             "homepage": "https://a24films.com/films/past-lives",
#             "id": 666277,
#             "imdb_id": "tt13238346",
#             "original_language": "en",
#             "original_title": "Past Lives",
#             "overview": "Nora and Hae Sung, two childhood friends, are reunited in New York for one fateful week as they confront notions of destiny, love, and the choices that make a life.",
#             "popularity": 91.993,
#             "poster_path": "/k3waqVXSnvCZWfJYNtdamTgTtTA.jpg",
#             "production_companies": [
#                 {
#                     "id": 41077,
#                     "logo_path": "/1ZXsGaFPgrgS6ZZGS37AqD5uU12.png",
#                     "name": "A24",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 1422,
#                     "logo_path": "/rIB6DuimR1qgLE14cBwpMABC2xx.png",
#                     "name": "Killer Films",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 158407,
#                     "logo_path": "/zUj7hFnsY8y1hVPfiZYnDtcGTHe.png",
#                     "name": "2AM",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 128404,
#                     "logo_path": "/dP3usmr6di1jMPH738rvbxdkmSQ.png",
#                     "name": "CJ ENM",
#                     "origin_country": "KR"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "KR",
#                     "name": "South Korea"
#                 },
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-06-02",
#             "revenue": 15348213,
#             "runtime": 106,
#             "spoken_languages": [
#                 {
#                     "english_name": "Korean",
#                     "iso_639_1": "ko",
#                     "name": "\ud55c\uad6d\uc5b4/\uc870\uc120\ub9d0"
#                 },
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "",
#             "title": "Past Lives",
#             "video": false,
#             "vote_average": 7.879,
#             "vote_count": 257
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/3xYPGRUsXCZj7rKOzvOY84JCafK.jpg",
#             "belongs_to_collection": null,
#             "budget": 0,
#             "genres": [
#                 {
#                     "id": 18,
#                     "name": "Drama"
#                 },
#                 {
#                     "id": 10749,
#                     "name": "Romance"
#                 }
#             ],
#             "homepage": "http://a24films.com/films/priscilla",
#             "id": 1020006,
#             "imdb_id": "tt22041854",
#             "original_language": "en",
#             "original_title": "Priscilla",
#             "overview": "When teenage Priscilla Beaulieu meets Elvis Presley at a party, the man who is already a meteoric rock-and-roll superstar becomes someone entirely unexpected in private moments: a thrilling crush, an ally in loneliness, a vulnerable best friend.",
#             "popularity": 63.949,
#             "poster_path": "/3eTAdKJzC8biM52Eii1ghk69bMP.jpg",
#             "production_companies": [
#                 {
#                     "id": 70,
#                     "logo_path": "/ueaENQkPcy8rlr5fGZVBXKOhlBh.png",
#                     "name": "American Zoetrope",
#                     "origin_country": "US"
#                 },
#                 {
#                     "id": 128344,
#                     "logo_path": "/zNBa6RAZ5TKWZUEhxx6sxc9tdrr.png",
#                     "name": "The Apartment Pictures",
#                     "origin_country": "IT"
#                 }
#             ],
#             "production_countries": [
#                 {
#                     "iso_3166_1": "IT",
#                     "name": "Italy"
#                 },
#                 {
#                     "iso_3166_1": "US",
#                     "name": "United States of America"
#                 }
#             ],
#             "release_date": "2023-10-26",
#             "revenue": 0,
#             "runtime": 110,
#             "spoken_languages": [
#                 {
#                     "english_name": "English",
#                     "iso_639_1": "en",
#                     "name": "English"
#                 }
#             ],
#             "status": "Released",
#             "tagline": "Wife to the king. Icon to the world. Destined for more.",
#             "title": "Priscilla",
#             "video": false,
#             "vote_average": 7.0,
#             "vote_count": 10
#         }
#     ]
# }

# %%
df = pd.DataFrame(json_dict["results"])
df
# Out:
#     adult                     backdrop_path  \
# 0   False  /7NRGAtu8E4343NSKwhkgmVRDINw.jpg
# 1   False  /pA3vdhadJPxF5GA1uo8OPTiNQDT.jpg
# 2   False  /mv8M0PqQYicndU7TGgBAHrI4uUo.jpg
# 3   False  /45zVtZx6Tzx3RKeDziK25K9geFf.jpg
# 4   False  /xHqTnPtpd9Qd7R0fVtoqxZYM67Q.jpg
# 5   False  /mfm4srsPALxaeOMFFFJ0drXTyXy.jpg
# 6   False  /5vHvR0fEVuypYZ7TOJTQWPfs3tI.jpg
# 7   False  /cRdA9xjHBbobw4LJFsQ3j1CgpVq.jpg
# 8   False  /cofs7Y72FkRjALbOOOz8q7Uty6h.jpg
# 9   False  /a0GM57AnJtNi7lMOCamniiyV10W.jpg
# 10  False  /qZOuoBoKCDLSm1EvYz2eBub8Cto.jpg
# 11  False  /hon92J1oqdrTwcGHXG64G2bXqrJ.jpg
# 12  False  /mEcCz4Nzw57wJIXo6g69q9NUQih.jpg
# 13  False  /8g9ZdvHX6jszRY71aVtpRUmHQzJ.jpg
# 14  False  /wOYDsD7WIKsz5DtrnjsvCcEyFJa.jpg
# 15  False  /5ut2rC5H1YE0GnNPpl1csnNvqum.jpg
# 16  False  /eXX9PqCgbTVYnnlbGuAz7Lk4E86.jpg
# 17  False  /drfl2eWipiibW3u3Ybx9HQ8VgIn.jpg
# 18  False  /rron9HAuS9s7zBF8iCX1tsafxUo.jpg
# 19  False  /3xYPGRUsXCZj7rKOzvOY84JCafK.jpg
#
#                                 belongs_to_collection     budget  \
# 0                                                None   20000000
# 1                                                None   14500000
# 2                                                None          0
# 3   {'id': 489724, 'name': 'The Trolls Collection'...          0
# 4                                                None   50000000
# 5                                                None   46000000
# 6   {'id': 623911, 'name': 'Captain Marvel Collect...  274800000
# 7   {'id': 727761, 'name': 'Terrifier Collection',...     250000
# 8                                                None         91
# 9                                                None          0
# 10                                               None          0
# 11                                               None  100000000
# 12                                               None  200000000
# 13                                               None          0
# 14                                               None          0
# 15  {'id': 644309, 'name': 'The White Storm Collec...          0
# 16                                               None          0
# 17                                               None          0
# 18                                               None   12000000
# 19                                               None          0
#
#                                                genres  \
# 0   [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 2   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 3   [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 4   [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 5   [{'id': 35, 'name': 'Comedy'}, {'id': 12, 'nam...
# 6   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 7   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 8   [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 9   [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 10  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 11  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 12  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 13  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 14  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 15  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 16  [{'id': 27, 'name': 'Horror'}, {'id': 12, 'nam...
# 17  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 18  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 19  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                              homepage       id     imdb_id  \
# 0               https://www.fivenightsatfreddys.movie   507089   tt4589218
# 1                https://www.soundoffreedommovie.com/   678512   tt7599146
# 2                                                       744857  tt16300962
# 3   https://www.dreamworks.com/movies/trolls-band-...   901362  tt14362112
# 4   https://www.bluefoxentertainment.com/films/the...   958006  tt11908172
# 5             https://www.uphe.com/movies/strays-2023   912908  tt15153532
# 6           https://www.marvel.com/movies/the-marvels   609681  tt10676048
# 7                  http://www.terrifier2themovie.com/   663712  tt10403420
# 8                                                       944952  tt18363072
# 9      https://gkids.com/films/the-boy-and-the-heron/   508883   tt6587046
# 10                                                      939338  tt22360682
# 11                          https://hungergames.movie   695721  tt10545296
# 12                     https://movies.disney.com/wish  1022796  tt11304740
# 13                                                      958182  tt24079846
# 14                         https://www.napoleon.movie   753342  tt13287846
# 15                                                     1093485  tt26929966
# 16                                                     1145851  tt22050310
# 17                                                      841742  tt10916810
# 18              https://a24films.com/films/past-lives   666277  tt13238346
# 19                http://a24films.com/films/priscilla  1020006  tt22041854
#
#    original_language                                     original_title  ...  \
# 0                 en                            Five Nights at Freddy's  ...
# 1                 en                                   Sound of Freedom  ...
# 2                 es                            Cuando acecha la maldad  ...
# 3                 en                               Trolls Band Together  ...
# 4                 en                                      The Kill Room  ...
# 5                 en                                             Strays  ...
# 6                 en                                        The Marvels  ...
# 7                 en                                        Terrifier 2  ...
# 8                 en                                    The Royal Hotel  ...
# 9                 ja                                         君たちはどう生きるか  ...
# 10                fr                    Pattie et la colère de Poséidon  ...
# 11                en  The Hunger Games: The Ballad of Songbirds & Sn...  ...
# 12                en                                               Wish  ...
# 13                es                                            Heroico  ...
# 14                en                                           Napoleon  ...
# 15                cn                                           掃毒3︰人在天涯  ...
# 16                es                                 El hombre del saco  ...
# 17                fr                                       Megalomaniac  ...
# 18                en                                         Past Lives  ...
# 19                en                                          Priscilla  ...
#
#    release_date    revenue runtime  \
# 0    2023-10-25  152000000     110
# 1    2023-07-03  239366545     131
# 2    2023-10-05          0      99
# 3    2023-10-12   38200000      92
# 4    2023-09-14     476375      98
# 5    2023-08-17   32000000      93
# 6    2023-11-08          0     105
# 7    2022-10-06   15100000     138
# 8    2023-10-06     755034      91
# 9    2023-07-14   55800000     124
# 10   2023-01-25    4834952      95
# 11   2023-11-15          0     157
# 12   2023-11-22          0      92
# 13   2023-09-21          0      88
# 14   2023-11-22          0     157
# 15   2023-07-06          0     125
# 16   2023-08-11          0       0
# 17   2023-09-08          0     100
# 18   2023-06-02   15348213     106
# 19   2023-10-26          0     110
#
#                                      spoken_languages           status  \
# 0   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 1   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 2   [{'english_name': 'Spanish', 'iso_639_1': 'es'...         Released
# 3   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 4   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 5   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 6   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 7   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 8   [{'english_name': 'English', 'iso_639_1': 'en'...         Released
# 9   [{'english_name': 'Japanese', 'iso_639_1': 'ja...         Released
# 10  [{'english_name': 'Danish', 'iso_639_1': 'da',...         Released
# 11  [{'english_name': 'English', 'iso_639_1': 'en'...  Post Production
# 12  [{'english_name': 'English', 'iso_639_1': 'en'...  Post Production
# 13  [{'english_name': 'Spanish', 'iso_639_1': 'es'...         Released
# 14  [{'english_name': 'English', 'iso_639_1': 'en'...  Post Production
# 15  [{'english_name': 'Cantonese', 'iso_639_1': 'c...         Released
# 16  [{'english_name': 'Spanish', 'iso_639_1': 'es'...         Released
# 17  [{'english_name': 'French', 'iso_639_1': 'fr',...         Released
# 18  [{'english_name': 'Korean', 'iso_639_1': 'ko',...         Released
# 19  [{'english_name': 'English', 'iso_639_1': 'en'...         Released
#
#                                               tagline  \
# 0                        Can you survive five nights?
# 1          Fight for the light. Silence the darkness.
# 2                        There's no point in praying.
# 3             There are some new trolls on the block.
# 4                               Crime is an art form.
# 5                                  Go fetch yourself.
# 6                  Higher. Further. Faster. Together.
# 7                                 Who's laughing now?
# 8                 A fun adventure is all they wanted.
# 9
# 10                       Small heroes, big adventure.
# 11                    Everyone hungers for something.
# 12                      Be careful what you wish for.
# 13         There are no rights here, not even humans.
# 14     He came from nothing. He conquered everything.
# 15
# 16
# 17
# 18
# 19  Wife to the king. Icon to the world. Destined ...
#
#                                                 title  video vote_average  \
# 0                             Five Nights at Freddy's  False        8.296
# 1                                    Sound of Freedom  False        8.126
# 2                                     When Evil Lurks  False        7.590
# 3                                Trolls Band Together  False        6.327
# 4                                       The Kill Room  False        6.200
# 5                                              Strays  False        7.533
# 6                                         The Marvels  False        8.400
# 7                                         Terrifier 2  False        6.793
# 8                                     The Royal Hotel  False        5.864
# 9                               The Boy and the Heron  False        7.494
# 10                                         Epic Tails  False        7.000
# 11  The Hunger Games: The Ballad of Songbirds & Sn...  False        0.000
# 12                                               Wish  False        0.000
# 13                                             Heroic  False        6.300
# 14                                           Napoleon  False        0.000
# 15                  The White Storm 3: Heaven or Hell  False        6.512
# 16                                 El hombre del saco  False        5.700
# 17                                       Megalomaniac  False        6.192
# 18                                         Past Lives  False        7.879
# 19                                          Priscilla  False        7.000
#
#    vote_count
# 0        1481
# 1        1147
# 2         128
# 3          26
# 4          34
# 5         481
# 6           9
# 7        1465
# 8          33
# 9          85
# 10         45
# 11          0
# 12          0
# 13         10
# 14          0
# 15         41
# 16         33
# 17         13
# 18        257
# 19         10
#
# [20 rows x 25 columns]

# %%
df["imdb_id"]
# Out:
# 0      tt4589218
# 1      tt7599146
# 2     tt16300962
# 3     tt14362112
# 4     tt11908172
# 5     tt15153532
# 6     tt10676048
# 7     tt10403420
# 8     tt18363072
# 9      tt6587046
# 10    tt22360682
# 11    tt10545296
# 12    tt11304740
# 13    tt24079846
# 14    tt13287846
# 15    tt26929966
# 16    tt22050310
# 17    tt10916810
# 18    tt13238346
# 19    tt22041854
# Name: imdb_id, dtype: object
