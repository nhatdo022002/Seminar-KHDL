# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install minio
# Out:
# ...
#      ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#      ---------------------------------------- 78.3/78.3 kB 2.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

#url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"
url = "https://api.themoviedb.org/3/movie/550?api_key=781d8b0f33163181d96d61fa21ea16a4"
headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/hZkgoQYus5vegHoetLkCJzb17zJ.jpg","belongs_to_collection":null,"budget":63000000,"genres":[{"id":18,"name":"Drama"}],"homepage":"http://www.foxmovies.com/movies/fight-club","id":550,"imdb_id":"tt0137523","original_language":"en","original_title":"Fight Club","overview":"A ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground \"fight clubs\" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.","popularity":105.447,"poster_path":"/pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg","production_companies":[{"id":711,"logo_path":"/tEiIH5QesdheJmDAqQwvtN60727.png","name":"Fox 2000 Pictures","origin_country":"US"},{"id":508,"logo_path":"/7cxRWzi4LsVm4Utfpr1hfARNurT.png","name":"Regency Enterprises","origin_country":"US"},{"id":4700,"logo_path":"/A32wmjrs9Psf4zw0uaixF0GXfxq.png","name":"The Linson Company",
# ...

# %%
import requests

url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ODFkOGIwZjMzMTYzMTgxZDk2ZDYxZmEyMWVhMTZhNCIsInN1YiI6IjY1MWRhNmVkYzUwYWQyMDBhZDgyZDRlYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.jfoB836ahuG6GYsOsAOTORYACLJRO6V7mm0_IUxMLv4"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"dates":{"maximum":"2023-10-26","minimum":"2023-10-03"},"page":1,"results":[{"adult":false,"backdrop_path":"/pA3vdhadJPxF5GA1uo8OPTiNQDT.jpg","genre_ids":[28,18],"id":678512,"original_language":"en","original_title":"Sound of Freedom","overview":"The story of Tim Ballard, a former US government agent, who quits his job in order to devote his life to rescuing children from global sex traffickers.","popularity":1873.942,"poster_path":"/qA5kPYZA7FkVvqcEfJRoOy4kpHg.jpg","release_date":"2023-07-03","title":"Sound of Freedom","video":false,"vote_average":8,"vote_count":553},{"adult":false,"backdrop_path":"/mRGmNnh6pBAGGp6fMBMwI8iTBUO.jpg","genre_ids":[27,9648,53],"id":968051,"original_language":"en","original_title":"The Nun II","overview":"In 1956 France, a priest is violently murdered, and Sister Irene begins to investigate. She once again comes face-to-face with a powerful evil.","popularity":1867.519,"poster_path":"/5gzzkR7y3hnY8AD1wXjCnVlHba5.jpg","release_date":"2023-09-06","title":
# ...

# %%
import requests

url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ODFkOGIwZjMzMTYzMTgxZDk2ZDYxZmEyMWVhMTZhNCIsInN1YiI6IjY1MWRhNmVkYzUwYWQyMDBhZDgyZDRlYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.jfoB836ahuG6GYsOsAOTORYACLJRO6V7mm0_IUxMLv4"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"dates":{"maximum":"2023-12-20","minimum":"2023-11-29"},"page":1,"results":[{"adult":false,"backdrop_path":"/xgGGinKRL8xeRkaAR9RMbtyk60y.jpg","genre_ids":[16,10751,10402,14,35],"id":901362,"original_language":"en","original_title":"Trolls Band Together","overview":"When Branch’s brother, Floyd, is kidnapped for his musical talents by a pair of nefarious pop-star villains, Branch and Poppy embark on a harrowing and emotional journey to reunite the other brothers and rescue Floyd from a fate even worse than pop-culture obscurity.","popularity":2508.728,"poster_path":"/bkpPTZUdq31UGDovmszsg2CchiI.jpg","release_date":"2023-10-12","title":"Trolls Band Together","video":false,"vote_average":7.268,"vote_count":138},{"adult":false,"backdrop_path":"/f1AQhx6ZfGhPZFTVKgxG91PhEYc.jpg","genre_ids":[18,36,10752],"id":753342,"original_language":"en","original_title":"Napoleon","overview":"An epic that details the checkered rise and fall of French Emperor Napoleon Bonaparte and his relentless journ
# ...

# %%
import requests

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ODFkOGIwZjMzMTYzMTgxZDk2ZDYxZmEyMWVhMTZhNCIsInN1YiI6IjY1MWRhNmVkYzUwYWQyMDBhZDgyZDRlYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.jfoB836ahuG6GYsOsAOTORYACLJRO6V7mm0_IUxMLv4"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}

# %%
import requests

url = "https://api.themoviedb.org/3/trending/movie/day?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ODFkOGIwZjMzMTYzMTgxZDk2ZDYxZmEyMWVhMTZhNCIsInN1YiI6IjY1MWRhNmVkYzUwYWQyMDBhZDgyZDRlYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.jfoB836ahuG6GYsOsAOTORYACLJRO6V7mm0_IUxMLv4"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/kHlX3oqdD4VGaLpB8O78M25KfdS.jpg","id":945729,"title":"A Haunting in Venice","original_language":"en","original_title":"A Haunting in Venice","overview":"Celebrated sleuth Hercule Poirot, now retired and living in self-imposed exile in Venice, reluctantly attends a Halloween séance at a decaying, haunted palazzo. When one of the guests is murdered, the detective is thrust into a sinister world of shadows and secrets.","poster_path":"/1Xgjl22MkAZQUavvOeBqRehrvqO.jpg","media_type":"movie","genre_ids":[9648,53,80],"popularity":833.745,"release_date":"2023-09-13","video":false,"vote_average":6.817,"vote_count":883},{"adult":false,"backdrop_path":"/t5zCBSB5xMDKcDqe91qahCOUYVV.jpg","id":507089,"title":"Five Nights at Freddy's","original_language":"en","original_title":"Five Nights at Freddy's","overview":"Recently fired and desperate for work, a troubled young man named Mike agrees to take a position as a night security guard at an aband
# ...

# %%
import requests

url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ODFkOGIwZjMzMTYzMTgxZDk2ZDYxZmEyMWVhMTZhNCIsInN1YiI6IjY1MWRhNmVkYzUwYWQyMDBhZDgyZDRlYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.jfoB836ahuG6GYsOsAOTORYACLJRO6V7mm0_IUxMLv4"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"dates":{"maximum":"2023-11-29","minimum":"2023-11-08"},"page":1,"results":[{"adult":false,"backdrop_path":"/7NRGAtu8E4343NSKwhkgmVRDINw.jpg","genre_ids":[27,9648],"id":507089,"original_language":"en","original_title":"Five Nights at Freddy's","overview":"Recently fired and desperate for work, a troubled young man named Mike agrees to take a position as a night security guard at an abandoned theme restaurant: Freddy Fazbear's Pizzeria. But he soon discovers that nothing at Freddy's is what it seems.","popularity":4529.373,"poster_path":"/A4j8S6moJS2zNtRR8oWF08gRnL5.jpg","release_date":"2023-10-25","title":"Five Nights at Freddy's","video":false,"vote_average":8.292,"vote_count":1485},{"adult":false,"backdrop_path":"/pA3vdhadJPxF5GA1uo8OPTiNQDT.jpg","genre_ids":[28,18],"id":678512,"original_language":"en","original_title":"Sound of Freedom","overview":"The story of Tim Ballard, a former US government agent, who quits his job in order to devote his life to rescuing children from globa
# ...

# %%
import pandas as pd
#Đọc tệp TSV bằng Polars
df = pd.read_csv("name_basics.tsv", sep='\t')
#Hiển thị dữ liệu
df
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 12923126  nm9993714   Romeo del Rosario        \N        \N
# 12923127  nm9993716       Essias Loberg        \N        \N
# 12923128  nm9993717  Harikrishnan Rajan        \N        \N
# 12923129  nm9993718         Aayush Nair        \N        \N
# 12923130  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# ...

# %%
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12923131 entries, 0 to 12923130
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             object
#  1   primaryName        object
#  2   birthYear          object
#  3   deathYear          object
#  4   primaryProfession  object
#  5   knownForTitles     object
# dtypes: object(6)
# memory usage: 591.6+ MB
# None
# nconst                     0
# primaryName                6
# birthYear                  0
# deathYear                  0
# primaryProfession    2560188
# knownForTitles             0
# dtype: int64

# %%
import pandas as pd
#Đọc tệp TSV bằng Pandas
df2 = pd.read_csv("title_basics.tsv", sep='\t')
#Hiển thị dữ liệu
df2
# Out:
# C:\Users\Nhatd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3505: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10211020  tt9916848  tvEpisode              Episode #3.17
# 10211021  tt9916850  tvEpisode              Episode #3.19
# 10211022  tt9916852  tvEpisode              Episode #3.20
# 10211023  tt9916856      short                   The Wind
# 10211024  tt9916880  tvEpisode  Horrid Henry Knows It All
#
# ...

# %%
print(df2[df2['tconst'] == 'tt4589218'])
# Out:
#             tconst titleType             primaryTitle  \
# 7804323  tt4589218     movie  Five Nights at Freddy's
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 7804323  Five Nights at Freddy's       0      2023      \N            110
#
#          genres
# 7804323  Horror

# %% [markdown]
# # Lỗi ở 1 dòng data nên buộc phải xử lý trước khi import vào database

# %%
print(df2[df2['tconst'] == 'tt0701219'])
# Out:
#            tconst  titleType    primaryTitle   originalTitle isAdult  \
# 678244  tt0701219  tvEpisode  Summer of 4'2"  Summer of 4'2"       0
#
#        startYear endYear runtimeMinutes            genres
# 678244      1996      \N             30  Animation,Comedy

# %%
import pandas as pd
#Đọc tệp TSV bằng Polars
df3 = pd.read_csv("title_crew.tsv", sep='\t')
#Hiển thị dữ liệu
df3
# Out:
#              tconst            directors  \
# 0         tt0000001            nm0005690
# 1         tt0000002            nm0721526
# 2         tt0000003            nm0721526
# 3         tt0000004            nm0721526
# 4         tt0000005            nm0005690
# ...             ...                  ...
# 10232310  tt9916848            nm1485677
# 10232311  tt9916850            nm1485677
# 10232312  tt9916852            nm1485677
# 10232313  tt9916856           nm10538645
# 10232314  tt9916880  nm0584014,nm0996406
#
#                                                     writers
# 0                                                        \N
# 1                                                        \N
# 2                                                        \N
# 3                                                        \N
# 4                                                        \N
# ...                                                     ...
# ...

# %%
import pandas as pd
#Đọc tệp TSV bằng Polars
df4 = pd.read_csv("title_episode.tsv", sep='\t')
#Hiển thị dữ liệu
df4
# Out:
#             tconst parentTconst seasonNumber episodeNumber
# 0        tt0041951    tt0041038            1             9
# 1        tt0042816    tt0989125            1            17
# 2        tt0042889    tt0989125           \N            \N
# 3        tt0043426    tt0040051            3            42
# 4        tt0043631    tt0989125            2            16
# ...            ...          ...          ...           ...
# 7800113  tt9916846    tt1289683            3            18
# 7800114  tt9916848    tt1289683            3            17
# 7800115  tt9916850    tt1289683            3            19
# 7800116  tt9916852    tt1289683            3            20
# 7800117  tt9916880    tt0985991            4             2
#
# [7800118 rows x 4 columns]

# %%
import pandas as pd
#Đọc tệp TSV bằng Polars
df5 = pd.read_csv("title_principal.tsv", sep='\t')
#Hiển thị dữ liệu
df5
# Out:
#              tconst  ordering     nconst         category  \
# 0         tt0000001         1  nm1588970             self
# 1         tt0000001         2  nm0005690         director
# 2         tt0000001         3  nm0374658  cinematographer
# 3         tt0000002         1  nm0721526         director
# 4         tt0000002         2  nm1335271         composer
# ...             ...       ...        ...              ...
# 58519634  tt9916880         5  nm0584014         director
# 58519635  tt9916880         6  nm0996406         director
# 58519636  tt9916880         7  nm1482639           writer
# 58519637  tt9916880         8  nm2586970           writer
# 58519638  tt9916880         9  nm1594058         producer
#
#                               job characters
# 0                              \N   ["Self"]
# 1                              \N         \N
# 2         director of photography         \N
# 3                              \N         \N
# ...

# %%
print(df5[df5['tconst'] == 'tt4589218'])
# Out:
#              tconst  ordering     nconst  category              job  \
# 44667494  tt4589218        10  nm0089658  producer         producer
# 44667495  tt4589218         1  nm0000498     actor               \N
# 44667496  tt4589218         2  nm1242688     actor               \N
# 44667497  tt4589218         3  nm5634768   actress               \N
# 44667498  tt4589218         4  nm0000524   actress               \N
# 44667499  tt4589218         5  nm0849747  director               \N
# 44667500  tt4589218         6  nm6926569    writer    screenplay by
# 44667501  tt4589218         7  nm2417104    writer    screenplay by
# 44667502  tt4589218         8  nm3273770    writer  screen story by
# 44667503  tt4589218         9  nm3225709    writer  screen story by
#
#                 characters
# 44667494                \N
# 44667495  ["Steve Raglan"]
# 44667496          ["Mike"]
# 44667497       ["Vanessa"]
# 44667498     ["Aunt Jane"]
# 44667499                \N
# ...

# %%
df5["job"] = df5["job"].str.replace('"', '').astype(str)
df5["characters"] = df5["characters"].str.replace('"', '').astype(str)

# %%
file_path = "output_title_principal.tsv"
df5.to_csv(file_path, sep='\t', index=False)

# %%
# Tạo DataFrame từ file txt
import pandas as pd
df6 = pd.read_csv('title_rating.tsv', sep='\t')
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1355266 entries, 0 to 1355265
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1355266 non-null  object
#  1   averageRating  1355266 non-null  float64
#  2   numVotes       1355266 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 31.0+ MB

# %%
print(df6[df6['tconst'] == 'tt4589218'])
# Out:
# Empty DataFrame
# Columns: [tconst, averageRating, numVotes]
# Index: []

# %%
import pandas as pd
#Đọc tệp TSV bằng Polars
df2 = pd.read_csv("title_basicss.tsv", sep='\t')
#Hiển thị dữ liệu
df2
# Out:
# C:\Users\Nhatd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3505: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10211020  tt9916848  tvEpisode              Episode #3.17
# 10211021  tt9916850  tvEpisode              Episode #3.19
# 10211022  tt9916852  tvEpisode              Episode #3.20
# 10211023  tt9916856      short                   The Wind
# 10211024  tt9916880  tvEpisode  Horrid Henry Knows It All
#
# ...

# %%
df2.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
print(df2[df2['tconst'] == 'tt0701219'])
# Out:
#            tconst  titleType    primaryTitle   originalTitle isAdult  \
# 678244  tt0701219  tvEpisode  Summer of 4'2"  Summer of 4'2"       0
#
#        startYear endYear runtimeMinutes            genres
# 678244      1996      \N             30  Animation,Comedy

# %%
#df2[df2['tconst'] == 'tt0701219']
df2["primaryTitle"] = df2["primaryTitle"].str.replace('"', '').astype(str)
df2["originalTitle"] = df2["originalTitle"].str.replace('"', '').astype(str)

# %%
print(df2[df2['tconst'] == 'tt0701219'])
# Out:
#            tconst  titleType   primaryTitle  originalTitle isAdult startYear  \
# 678244  tt0701219  tvEpisode  Summer of 4'2  Summer of 4'2       0      1996
#
#        endYear runtimeMinutes            genres
# 678244      \N             30  Animation,Comedy

# %%
df2
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10211020  tt9916848  tvEpisode              Episode #3.17
# 10211021  tt9916850  tvEpisode              Episode #3.19
# 10211022  tt9916852  tvEpisode              Episode #3.20
# 10211023  tt9916856      short                   The Wind
# 10211024  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# ...

# %%
file_path = "output123.tsv"
df2.to_csv(file_path, sep='\t', index=False)

# %%
import minio
from minio import Minio
#from minio.error import ResponseError

# %%
pip install minio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from minio.error import ResponseError
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from minio.error import ResponseError
#
# ImportError: cannot import name 'ResponseError' from 'minio.error' (C:\Users\Nhatd\anaconda3\lib\site-packages\minio\error.py)

# %%
#Thông tin kết nối đến MinIO server
minio_client = Minio(
    "443",  # Điền vào địa chỉ MinIO server của bạn
    access_key="jUR9KgWerlAL8T1XkUFp",
    secret_key="n5YRiDb6PYXwiFO1RTg2bxkzWW3GQtPYF3lp7vhY",
    secure=True  # Sử dụng True nếu bạn sử dụng kết nối bảo mật (HTTPS)
)

#Tên bucket chứa tệp TSV
bucket_name = "seminar"

#Tên tệp TSV bạn muốn đọc
object_name = "title_basics.tsv"

    # Đọc nội dung tệp TSV từ MinIO
data = minio_client.get_object(bucket_name, object_name)

#Đọc nội dung và hiển thị nó
for line in data.stream(32 * 1024):  # Đọc 32 KB mỗi lần
    print(line.decode('utf-8'))  # Giả sử tệp TSV sử dụng mã hóa UTF-8

# except ResponseError as err:
#     print("Lỗi MinIO: {0}".format(err))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\lib\socket.py:954, in getaddrinfo(host, port, family, type, proto, flags)
#     953 addrlist = []
# ...
